# %% [markdown]
# ## MSTICPy and Notebooks in InfoSec
# ---
#
# # <a style="border: solid; padding:5pt; color:black; background-color:#909090">Session 3 - Acquiring Data Using MSTICPy</a>
#
# ---
#
# ## What this session covers:
#  - Setting up query providers
#  - Connecting to providers
#  - Querying for data
#  - Offline data options
#
# ## Prerequisites
# - Python >= 3.8 Environment
# - Jupyter installed
# - MSTICPy
# - The msticpyconfig.yaml file you recently populated

# %% [markdown]
# ### MSTICPy has a number of supported data providers
# - Microsoft Sentinel
# - Microsoft Defender/Defender for Endpoint
# - Splunk
# - Sumologic
# - Microsoft Graph
# - Local data
# - Mordor/Security Datasets
# - Kusto/Azure Data Explorer
# - Azure Resource Graph
#
# These provide way to connect to and query data from these sources in a structured and standardized way.<br>
# The providers also provide a way to create, store and call templated queries simply and easily.
#
# Ref: https://msticpy.readthedocs.io/en/latest/DataAcquisition.html

# %%
#Set up MSTICPy
import msticpy as mp 
mp.init_notebook()

# %% [markdown]
# The QueryProvider handles this functionality and can be configured to work with the supported data sources.
#
# `list_data_environments` shows us the names of the providers available to us.

# %%
mp.QueryProvider.list_data_environments()
# Out:
# ['MSSentinel',
#  'AzureSentinel',
#  'LogAnalytics',
#  'Kusto',
#  'AzureSecurityCenter',
#  'MSGraph',
#  'SecurityGraph',
#  'MDE',
#  'MDATP',
#  'LocalData',
#  'Splunk',
#  'OTRF',
#  'Mordor',
#  'ResourceGraph',
#  'Sumologic',
#  'M365D',
#  'Cybereason',
#  'Elastic',
#  'OSQueryLogs',
#  'MSSentinel_New',
#  'Kusto_New']

# %% [markdown]
# You can then pass the name of the required provider to `QueryProvider`.

# %%
qry_prov = mp.QueryProvider("MSSentinel")
# Out:
# Please wait. Loading Kqlmagic extension...done
# Warning: Custom query definitions path E:\src\msticpy-training\workshops\Jun2023\completed\data not found

# %% [markdown]
# ---
#
# # <a style="border: solid; padding:5pt; color:black; background-color:#909090">Authenticating to Providers</a>
#
# ---
#
# Once we have created our QueryProvider for the data source we want the next step is to connect the provider to the source and authenticate. <br>
# In order to connect we need to tell the provider which instance to connect to, i.e. what workspace, cluster, or database.<br>
#
# To do that we need to provide a set of connection parameters or a *connection string*.<br>
# We can do this **manually** or we can store these details in our `msticpyconfig file` and pull them directly from there.<br>
#
# First, we are going to connect using a manually-created connection string, and later using our config file, which is a much more manageable way of handling it.
#
# The connection parameters typically require the following information:
# - An ID of the resource to connect to
# - An indicator of the credential type you want to use to authenticate
# - The ID of the authority (AAD) that will authenticate/authorize the connection.
# - Data source specific parameters (e.g. DefaultDatabase)
#
# > Note: Some of these may inherit from your account or other settings
#
# The authentication method for the provider will depend on the type of providers, and what is supported.<br>
# We don't have the breadth to cover all of the options here today but most providers have a authentication method that requires the user to log in each time, either via an interactive login, or device code login.<br>
# However we can also configure most providers to use tokens already on a host, such as MSI and Azure CLI tokens. This removes the need to authenticate each time.<br>
#
# Generally for Microsoft services the following options are supported:
#  - Interactive/Device Code
#  - Azure CLI
#  - MSI
#  - Creds stored as Environment Variables
#  - VSCode or PowerShell Credentials
#
# Some other providers (such as Defender) use app level authentication instead. The documentation will detail what authentication options are possible for each provider.
#
# ### Using an connection string to connect
# Below we will connect with a specific connection string, and the default auth method for this provider - Device Code.
#
# Ref: https://msticpy.readthedocs.io/en/latest/data_acquisition/DataProviders.html

# %%
la_connection_string = f'loganalytics://code().tenant("72f988bf-86f1-41af-91ab-2d7cd011db47").workspace("8ecf8077-cf51-4820-aadd-14040956f35d")'
qry_prov.connect(connection_str=la_connection_string)
# Out:
# Connecting...
# <!DOCTYPE html>
#             <html><body>
#             <div style=''>
#             <a href='http://127.0.0.1:58680/webbrowser?url=http%3A//127.0.0.1%3A58680/files/.kqlmagic/temp_files/v2-21016csgVjLM4M8vh/popup__8ecf8077-cf51-4820-aadd-14040956f35d_at_loganalytics_schema.html%3Fkernelid%3Dv2-21016csgVjLM4M8vh&kernelid=v2-21016csgVjLM4M8vh' style='padding: 2px 6px 2px 6px; color: #333333; background-color: #EEEEEE; border-top: 1px solid #CCCCCC; border-right: 1px solid #333333; border-bottom: 1px solid #333333; border-left: 1px solid #CCCCCC' target='popup__8ecf8077-cf51-4820-aadd-14040956f35d_at_loganalytics_schema'>popup schema 8ecf8077-cf51-4820-aadd-14040956f35d@loganalytics</a>
#             </div>
#             </body></html>
# connected

# %% [markdown]
# As we can see the above method is a bit cumbersome for every day use - having a more seamless authentication method, and storing workspace details in config is much smoother.
#
# To use the a settings from our config instead of the connection string we can use the<br>
# `workspace` parameter pull the settings from file and pass them to the connection method.<br>
#
# We are also going explicitly request to use Azure CLI credentials using the `auth_methods` parameter.<br>
# You typically don't need to do this unless you want to override the defaults in `msticpyconfig.yaml`
# <br>
#
# ---
# **Note -**
# You only need to perform the CLI authentication once per token lifetime rather than every time you connect.<br>
# If you've done this already today, you probably don't need to do it again.

# %%
# !az login

# %% [markdown]
# Now when we connect to our QueryProvider we can tell the provider to use CLI authentication.
#
# ---
# **Note -**
# The authentication methods are passed as a list, this is because you can often provide multiple options that it will use in order until it successfully authenticates.
#
# If you have configured default credential types in your `msticpyconfig.yaml`,
# you don't need to use the `auth_methods` parameter unless you
# need to override these.
#
# ```yaml
# Azure:
#   auth_methods:
#   - cli
#   - msi
#   - devicecode
#   cloud: global
# ```

# %%
qry_prov = mp.QueryProvider("MSSentinel_New")
qry_prov.connect(workspace="Default", auth_methods=['cli'])
# Out:
# Warning: Custom query definitions path E:\src\msticpy-training\workshops\Jun2023\completed\data not found
# connected

# %% [markdown]
# Once connected we can start running queries to get data.
# We can do this with the built in queries or with our own queries.
#
# We will start with the built in queries. We can list the available queries with `list_queries`.
#
# Ref: https://msticpy.readthedocs.io/en/latest/DataAcquisition.html#built-in-data-queries

# %%
qry_prov.list_queries()
# Out:
# ['Azure.get_vmcomputer_for_host',
#  'Azure.get_vmcomputer_for_ip',
#  'Azure.list_aad_signins_for_account',
#  'Azure.list_aad_signins_for_ip',
#  'Azure.list_all_signins_geo',
#  'Azure.list_azure_activity_for_account',
#  'Azure.list_azure_activity_for_ip',
#  'Azure.list_azure_activity_for_resource',
#  'Azure.list_storage_ops_for_hash',
#  'Azure.list_storage_ops_for_ip',
#  'AzureNetwork.all_network_connections_csl',
#  'AzureNetwork.az_net_analytics',
#  'AzureNetwork.dns_lookups_for_domain',
#  'AzureNetwork.dns_lookups_for_ip',
#  'AzureNetwork.dns_lookups_from_ip',
#  'AzureNetwork.get_heartbeat_for_host',
#  'AzureNetwork.get_heartbeat_for_ip',
#  'AzureNetwork.get_host_for_ip',
#  'AzureNetwork.get_ips_for_host',
#  'AzureNetwork.host_network_connections_csl',
#  'AzureNetwork.hosts_by_ip_csl',
#  'AzureNetwork.ip_network_connections_csl',
#  'AzureNetwork.ips_by_host_csl',
#  'AzureNetwork.list_azure_network_flows_by_host',
#  'AzureNetwork.list_azure_network_flows_by_ip',
#  'AzureNetwork.network_connections_to_url',
#  'AzureSentinel.get_bookmark_by_id',
#  'AzureSentinel.get_bookmark_by_name',
#  'AzureSentinel.get_dynamic_summary_by_id',
#  'AzureSentinel.get_dynamic_summary_by_name',
#  'AzureSentinel.list_bookmarks',
#  'AzureSentinel.list_bookmarks_for_entity',
#  'AzureSentinel.list_bookmarks_for_tags',
#  'AzureSentinel.list_dynamic_summaries',
#  'Heartbeat.get_heartbeat_for_host',
#  'Heartbeat.get_heartbeat_for_ip',
#  'Heartbeat.get_info_by_hostname',
#  'Heartbeat.get_info_by_ipaddress',
#  'LinuxAudit.auditd_all',
#  'LinuxSyslog.all_syslog',
#  'LinuxSyslog.cron_activity',
#  'LinuxSyslog.list_account_logon_failures',
#  'LinuxSyslog.list_host_logon_failures',
#  'LinuxSyslog.list_ip_logon_failures',
#  'LinuxSyslog.list_logon_failures',
#  'LinuxSyslog.list_logons_for_account',
#  'LinuxSyslog.list_logons_for_host',
#  'LinuxSyslog.list_logons_for_source_ip',
#  'LinuxSyslog.notable_events',
#  'LinuxSyslog.squid_activity',
#  'LinuxSyslog.sudo_activity',
#  'LinuxSyslog.summarize_events',
#  'LinuxSyslog.sysmon_process_events',
#  'LinuxSyslog.user_group_activity',
#  'LinuxSyslog.user_logon',
#  'MDATP.file_path',
#  'MDATP.host_connections',
#  'MDATP.ip_connections',
#  'MDATP.list_connections',
#  'MDATP.list_filehash',
#  'MDATP.list_files',
#  'MDATP.list_host_processes',
#  'MDATP.process_cmd_line',
#  'MDATP.process_creations',
#  'MDATP.process_paths',
#  'MDATP.protocol_connections',
#  'MDATP.url_connections',
#  'MDATP.user_files',
#  'MDATP.user_logons',
#  'MDATP.user_network',
#  'MDATP.user_processes',
#  'MDATPHunting.accessibility_persistence',
#  'MDATPHunting.av_sites',
#  'MDATPHunting.b64_pe',
#  'MDATPHunting.brute_force',
#  'MDATPHunting.cve_2018_1000006l',
#  'MDATPHunting.cve_2018_1111',
#  'MDATPHunting.cve_2018_4878',
#  'MDATPHunting.doc_with_link',
#  'MDATPHunting.dropbox_link',
#  'MDATPHunting.email_link',
#  'MDATPHunting.email_smartscreen',
#  'MDATPHunting.malware_recycle',
#  'MDATPHunting.network_scans',
#  'MDATPHunting.powershell_downloads',
#  'MDATPHunting.service_account_powershell',
#  'MDATPHunting.smartscreen_ignored',
#  'MDATPHunting.smb_discovery',
#  'MDATPHunting.tor',
#  'MDATPHunting.uncommon_powershell',
#  'MDATPHunting.user_enumeration',
#  'MDE.accessibility_persistence',
#  'MDE.av_sites',
#  'MDE.b64_pe',
#  'MDE.brute_force',
#  'MDE.cve_2018_1000006l',
#  'MDE.cve_2018_1111',
#  'MDE.cve_2018_4878',
#  'MDE.doc_with_link',
#  'MDE.dropbox_link',
#  'MDE.email_link',
#  'MDE.email_smartscreen',
#  'MDE.file_path',
#  'MDE.host_connections',
#  'MDE.ip_connections',
#  'MDE.list_connections',
#  'MDE.list_filehash',
#  'MDE.list_files',
#  'MDE.list_host_processes',
#  'MDE.malware_recycle',
#  'MDE.network_scans',
#  'MDE.powershell_downloads',
#  'MDE.process_cmd_line',
#  'MDE.process_creations',
#  'MDE.process_paths',
#  'MDE.protocol_connections',
#  'MDE.service_account_powershell',
#  'MDE.smartscreen_ignored',
#  'MDE.smb_discovery',
#  'MDE.tor',
#  'MDE.uncommon_powershell',
#  'MDE.url_connections',
#  'MDE.user_enumeration',
#  'MDE.user_files',
#  'MDE.user_logons',
#  'MDE.user_network',
#  'MDE.user_processes',
#  'MSSentinel.get_bookmark_by_id',
#  'MSSentinel.get_bookmark_by_name',
#  'MSSentinel.get_dynamic_summary_by_id',
#  'MSSentinel.get_dynamic_summary_by_name',
#  'MSSentinel.list_bookmarks',
#  'MSSentinel.list_bookmarks_for_entity',
#  'MSSentinel.list_bookmarks_for_tags',
#  'MSSentinel.list_dynamic_summaries',
#  'MultiDataSource.get_timeseries_anomalies',
#  'MultiDataSource.get_timeseries_data',
#  'MultiDataSource.get_timeseries_decompose',
#  'MultiDataSource.plot_timeseries_datawithbaseline',
#  'MultiDataSource.plot_timeseries_scoreanomolies',
#  'Network.all_network_connections_csl',
#  'Network.get_heartbeat_for_host',
#  'Network.get_heartbeat_for_ip',
#  'Network.get_host_for_ip',
#  'Network.get_ips_for_host',
#  'Network.host_network_connections_csl',
#  'Network.hosts_by_ip_csl',
#  'Network.ip_network_connections_csl',
#  'Network.ips_by_host_csl',
#  'Network.list_azure_network_flows_by_host',
#  'Network.list_azure_network_flows_by_ip',
#  'Network.network_connections_to_url',
#  'Office365.list_activity_for_account',
#  'Office365.list_activity_for_ip',
#  'Office365.list_activity_for_resource',
#  'SecurityAlert.get_alert',
#  'SecurityAlert.list_alerts',
#  'SecurityAlert.list_alerts_counts',
#  'SecurityAlert.list_alerts_for_ip',
#  'SecurityAlert.list_related_alerts',
#  'ThreatIntelligence.list_indicators',
#  'ThreatIntelligence.list_indicators_by_domain',
#  'ThreatIntelligence.list_indicators_by_email',
#  'ThreatIntelligence.list_indicators_by_filepath',
#  'ThreatIntelligence.list_indicators_by_hash',
#  'ThreatIntelligence.list_indicators_by_ip',
#  'ThreatIntelligence.list_indicators_by_url',
#  'WindowsSecurity.account_change_events',
#  'WindowsSecurity.get_host_logon',
#  'WindowsSecurity.get_parent_process',
#  'WindowsSecurity.get_process_tree',
#  'WindowsSecurity.list_all_logons_by_host',
#  'WindowsSecurity.list_events',
#  'WindowsSecurity.list_events_by_id',
#  'WindowsSecurity.list_host_events',
#  'WindowsSecurity.list_host_events_by_id',
#  'WindowsSecurity.list_host_logon_failures',
#  'WindowsSecurity.list_host_logons',
#  'WindowsSecurity.list_host_processes',
#  'WindowsSecurity.list_hosts_matching_commandline',
#  'WindowsSecurity.list_logon_attempts_by_account',
#  'WindowsSecurity.list_logon_attempts_by_ip',
#  'WindowsSecurity.list_logon_failures_by_account',
#  'WindowsSecurity.list_logons_by_account',
#  'WindowsSecurity.list_matching_processes',
#  'WindowsSecurity.list_other_events',
#  'WindowsSecurity.list_processes_in_session',
#  'WindowsSecurity.notable_events',
#  'WindowsSecurity.schdld_tasks_and_services',
#  'WindowsSecurity.summarize_events']

# %% [markdown]
# We can also use `browse` to get a clearer view of what's available
#
# <div style="border: solid; padding: 5pt; background-color: blue"><b>Warning</b> Browser is not working in training environment.</div>

# %%
qry_prov.browse()
# Out:
# VBox(children=(Text(value='Azure.get_vmcomputer_for_host', description='Filter:', style=TextStyle(description_…
# <hr>
# <h3>Gets latest VMComputer record for Host</h3><div></div><p><b>Parameters</b></p><div>add_query_items: str (optional)</div><div style='margin-left: 40px'>    Additional query clauses</div><div>end: datetime</div><div style='margin-left: 40px'>    Query end time</div><div>host_name: str</div><div style='margin-left: 40px'>    The Computer name of the VM</div><div>start: datetime</div><div style='margin-left: 40px'>    Query start time</div><div>table: str (optional)</div><div style='margin-left: 40px'>    Table name</div><div style='margin-left: 40px'>    (default value is: VMComputer)</div><br><p><b>Query</b></p><pre>{table}
# | where TimeGenerated >= datetime({start})
# | where TimeGenerated <= datetime({end})
# | where Computer has "{host_name}"
# | take 1</pre><br>
#         <p><b>Example</b></p>
#         <p>{QueryProvider}[.QueryPath].QueryName(params...)</p>
#         <pre>qry_prov.Azure.get_vmcomputer_for_host(start=start, end=end, hostname=host)</pre>

# %% [markdown]
# You can also search for a query:
# - just supply a string or regex (or a list of search terms) to search over all query metadata
# - search for queries using a specific table name (`table="DeviceProcessEvents")
# - search for queries using a specific parameter name
#
# Examples:
# ```python
# qry_prov.search("ip_address")
# qry_prov.search("ip_address", table="Office")
# qry_prov.search(param="URL")
# ```

# %%
qry_prov.search("Network")
# Out:
# ['AzureNetwork.all_network_connections_csl',
#  'AzureNetwork.az_net_analytics',
#  'AzureNetwork.get_host_for_ip',
#  'AzureNetwork.get_ips_for_host',
#  'AzureNetwork.host_network_connections_csl',
#  'AzureNetwork.ip_network_connections_csl',
#  'AzureNetwork.list_azure_network_flows_by_host',
#  'AzureNetwork.list_azure_network_flows_by_ip',
#  'AzureNetwork.network_connections_to_url',
#  'MDATP.host_connections',
#  'MDATP.ip_connections',
#  'MDATP.list_connections',
#  'MDATP.protocol_connections',
#  'MDATP.url_connections',
#  'MDATP.user_network',
#  'MDATPHunting.cve_2018_1111',
#  'MDATPHunting.cve_2018_4878',
#  'MDATPHunting.email_link',
#  'MDATPHunting.network_scans',
#  'MDATPHunting.smb_discovery',
#  'MDATPHunting.tor',
#  'MDE.cve_2018_1111',
#  'MDE.cve_2018_4878',
#  'MDE.email_link',
#  'MDE.host_connections',
#  'MDE.ip_connections',
#  'MDE.list_connections',
#  'MDE.network_scans',
#  'MDE.protocol_connections',
#  'MDE.smb_discovery',
#  'MDE.tor',
#  'MDE.url_connections',
#  'MDE.user_network',
#  'Network.all_network_connections_csl',
#  'Network.get_host_for_ip',
#  'Network.get_ips_for_host',
#  'Network.host_network_connections_csl',
#  'Network.ip_network_connections_csl',
#  'Network.list_azure_network_flows_by_host',
#  'Network.list_azure_network_flows_by_ip',
#  'Network.network_connections_to_url',
#  'ThreatIntelligence.list_indicators_by_ip']

# %%
qry_prov.search(param="url")
# Out:
# ['AzureNetwork.network_connections_to_url',
#  'AzureSentinel.list_bookmarks_for_entity',
#  'MDATP.url_connections',
#  'MDE.url_connections',
#  'MSSentinel.list_bookmarks_for_entity',
#  'Network.network_connections_to_url',
#  'ThreatIntelligence.list_indicators_by_url']

# %% [markdown]
# ### Running a query is a function call
#
# ```python3
# qry_prov.list_queries()
# ```
# ```
# ['Azure.get_vmcomputer_for_host',
#  'Azure.get_vmcomputer_for_ip',
#  'Azure.list_aad_signins_for_account',
#  'Azure.list_aad_signins_for_ip',
#  'Azure.list_all_signins_geo',  <<<<--- The query we want
#  'Azure.list_azure_activity_for_account',
#  'Azure.list_azure_activity_for_ip',
#  'Azure.list_azure_activity_for_resource',
# ```
#
# Append to the query provider with a dot
# ```python3
# qry_prov.Azure.list_all_signins_geo()
# ```

# %%
df = qry_prov.Azure.list_all_signins_geo()
df.head()
# Out:
#                                TenantId SourceSystem  \
# 0  8ecf8077-cf51-4820-aadd-14040956f35d     Azure AD
# 1  8ecf8077-cf51-4820-aadd-14040956f35d     Azure AD
# 2  8ecf8077-cf51-4820-aadd-14040956f35d     Azure AD
# 3  8ecf8077-cf51-4820-aadd-14040956f35d     Azure AD
# 4  8ecf8077-cf51-4820-aadd-14040956f35d     Azure AD
#
#                      TimeGenerated  \
# 0 2023-06-24 22:27:38.836729+00:00
# 1 2023-06-24 22:36:24.123888+00:00
# 2 2023-06-24 22:37:05.104393+00:00
# 3 2023-06-24 23:23:23.683707+00:00
# 4 2023-06-24 23:23:30.865893+00:00
#
#                                                                  ResourceId  \
# 0  /tenants/4b2462a4-bbee-495a-a0e1-f23ae524cc9c/providers/Microsoft.aadiam
# 1  /tenants/4b2462a4-bbee-495a-a0e1-f23ae524cc9c/providers/Microsoft.aadiam
# 2  /tenants/4b2462a4-bbee-495a-a0e1-f23ae524cc9c/providers/Microsoft.aadiam
# 3  /tenants/4b2462a4-bbee-495a-a0e1-f23ae524cc9c/providers/Microsoft.aadiam
# 4  /tenants/4b2462a4-bbee-495a-a0e1-f23ae524cc9c/providers/Microsoft.aadiam
#
#       OperationName OperationVersion    Category ResultType ResultSignature  \
# 0  Sign-in activity              1.0  SignInLogs      50055            None
# 1  Sign-in activity              1.0  SignInLogs          0            None
# 2  Sign-in activity              1.0  SignInLogs          0            None
# 3  Sign-in activity              1.0  SignInLogs          0            None
# 4  Sign-in activity              1.0  SignInLogs          0            None
#
#                              ResultDescription  DurationMs  \
# 0  Invalid password, entered expired password.           0
# 1                                                        0
# 2                                                        0
# 3                                                        0
# 4                                                        0
#
#                           CorrelationId          Resource     ResourceGroup  \
# 0  52510cc4-4f84-45d5-9a6e-ee90d827ceda  Microsoft.aadiam  Microsoft.aadiam
# 1  dd38984c-f239-4657-b4e3-5f482c975b2b  Microsoft.aadiam  Microsoft.aadiam
# 2  49b2c2c3-e660-4bc6-b322-559a45bb0e4b  Microsoft.aadiam  Microsoft.aadiam
# 3  804dc4e6-6322-4f07-a2ff-c17261e234eb  Microsoft.aadiam  Microsoft.aadiam
# 4  666c3c68-3993-4bdf-b596-6f46ed756e60  Microsoft.aadiam  Microsoft.aadiam
#
#   ResourceProvider                                               Identity  \
# 0                                                        Joanne Sensitive
# 1                   On-Premises Directory Synchronization Service Account
# 2                   On-Premises Directory Synchronization Service Account
# 3                   On-Premises Directory Synchronization Service Account
# 4                   On-Premises Directory Synchronization Service Account
#
#   Level Location                                   AlternateSignInName  \
# 0     4       AU                    joanne.sensitive@contosohotels.com
# 1     4       US  Sync_AADCON_a5225d32ba79@seccxpninja.onmicrosoft.com
# 2     4       US  Sync_AADCON_a5225d32ba79@seccxpninja.onmicrosoft.com
# 3     4       US    Sync_DC01_3862ce34675f@seccxpninja.onmicrosoft.com
# 4     4       US    Sync_DC01_3862ce34675f@seccxpninja.onmicrosoft.com
#
#                              AppDisplayName  \
# 0                                   CAttack
# 1  Microsoft Azure Active Directory Connect
# 2  Microsoft Azure Active Directory Connect
# 3  Microsoft Azure Active Directory Connect
# 4  Microsoft Azure Active Directory Connect
#
#                                   AppId  \
# 0  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 1  cb1056e2-e479-49de-ae31-7812af012ed8
# 2  cb1056e2-e479-49de-ae31-7812af012ed8
# 3  cb1056e2-e479-49de-ae31-7812af012ed8
# 4  cb1056e2-e479-49de-ae31-7812af012ed8
#
#                            AuthenticationContextClassReferences  \
# 0  [{"id":"urn:microsoft:req1","detail":"previouslySatisfied"}]
# 1  [{"id":"urn:microsoft:req1","detail":"previouslySatisfied"}]
# 2  [{"id":"urn:microsoft:req1","detail":"previouslySatisfied"}]
# 3  [{"id":"urn:microsoft:req1","detail":"previouslySatisfied"}]
# 4  [{"id":"urn:microsoft:req1","detail":"previouslySatisfied"}]
#
#                                                                                  AuthenticationDetails  \
# 0  [{"authenticationStepDateTime":"2023-06-24T22:25:57.3765269+00:00","authenticationMethod":"Passw...
# 1  [{"authenticationStepDateTime":"2023-06-24T22:35:45.4259726+00:00","authenticationMethod":"Passw...
# 2  [{"authenticationStepDateTime":"2023-06-24T22:35:38.9405639+00:00","authenticationMethod":"Passw...
# 3  [{"authenticationStepDateTime":"2023-06-24T23:21:30.1499764+00:00","authenticationMethod":"Passw...
# 4  [{"authenticationStepDateTime":"2023-06-24T23:21:17.1363144+00:00","authenticationMethod":"Passw...
#
#   AppliedEventListeners AuthenticationMethodsUsed  ... TokenIssuerName  \
# 0                  None                            ...
# 1                  None                            ...
# 2                  None                            ...
# 3                  None                            ...
# 4                  None                            ...
#
#   TokenIssuerType UserAgent  \
# 0         AzureAD
# 1         AzureAD
# 2         AzureAD
# 3         AzureAD
# 4         AzureAD
#
#                                          UserDisplayName  \
# 0                                       Joanne Sensitive
# 1  On-Premises Directory Synchronization Service Account
# 2  On-Premises Directory Synchronization Service Account
# 3  On-Premises Directory Synchronization Service Account
# 4  On-Premises Directory Synchronization Service Account
#
#                                  UserId  \
# 0  0a59bd32-5e0f-4103-8af7-7886e66cc473
# 1  2235a468-ad9c-4375-8008-0a7be76994a7
# 2  2235a468-ad9c-4375-8008-0a7be76994a7
# 3  ee856d98-cecd-4dbe-8833-bdeec67847d0
# 4  ee856d98-cecd-4dbe-8833-bdeec67847d0
#
#                                       UserPrincipalName  \
# 0                    joanne.sensitive@contosohotels.com
# 1  sync_aadcon_a5225d32ba79@seccxpninja.onmicrosoft.com
# 2  sync_aadcon_a5225d32ba79@seccxpninja.onmicrosoft.com
# 3    sync_dc01_3862ce34675f@seccxpninja.onmicrosoft.com
# 4    sync_dc01_3862ce34675f@seccxpninja.onmicrosoft.com
#
#                             AADTenantId UserType  FlaggedForReview  \
# 0  4b2462a4-bbee-495a-a0e1-f23ae524cc9c   Member              None
# 1  4b2462a4-bbee-495a-a0e1-f23ae524cc9c   Member              None
# 2  4b2462a4-bbee-495a-a0e1-f23ae524cc9c   Member              None
# 3  4b2462a4-bbee-495a-a0e1-f23ae524cc9c   Member              None
# 4  4b2462a4-bbee-495a-a0e1-f23ae524cc9c   Member              None
#
#   IPAddressFromResourceProvider  \
# 0
# 1
# 2
# 3
# 4
#
#                                        SignInIdentifier SignInIdentifierType  \
# 0                    joanne.sensitive@contosohotels.com
# 1  Sync_AADCON_a5225d32ba79@seccxpninja.onmicrosoft.com
# 2  Sync_AADCON_a5225d32ba79@seccxpninja.onmicrosoft.com
# 3    Sync_DC01_3862ce34675f@seccxpninja.onmicrosoft.com
# 4    Sync_DC01_3862ce34675f@seccxpninja.onmicrosoft.com
#
#                        ResourceTenantId                          HomeTenantId  \
# 0  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 1  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 2  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 3  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 4  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
#
#     UniqueTokenIdentifier  \
# 0  jxg0Fakjr0G8KtA6ygcOAA
# 1  24kpduQ5oUGccu__XkkOAA
# 2  iZwHDbvWYES03Ar1KkALAA
# 3  FB8RsXIBlEutQ3Vaf8wMAA
# 4  6KOCg0UNTku1k32ejz0JAA
#
#                                                                                SessionLifetimePolicies  \
# 0  [{"expirationRequirement":"rememberMultifactorAuthenticationOnTrustedDevices","detail":"Remember...
# 1  [{"expirationRequirement":"rememberMultifactorAuthenticationOnTrustedDevices","detail":"Remember...
# 2  [{"expirationRequirement":"rememberMultifactorAuthenticationOnTrustedDevices","detail":"Remember...
# 3  [{"expirationRequirement":"rememberMultifactorAuthenticationOnTrustedDevices","detail":"Remember...
# 4  [{"expirationRequirement":"rememberMultifactorAuthenticationOnTrustedDevices","detail":"Remember...
#
#   AutonomousSystemNumber AuthenticationProtocol CrossTenantAccessType  \
# 0                   8075                   ropc                  none
# 1                   8075                   ropc                  none
# 2                   8075                   ropc                  none
# 3                   8075                   ropc                  none
# 4                   8075                   ropc                  none
#
#   AppliedConditionalAccessPolicies RiskLevel        Type  Result  \
# 0                                             SigninLogs  Failed
# 1                                             SigninLogs  Sucess
# 2                                             SigninLogs  Sucess
# 3                                             SigninLogs  Sucess
# 4                                             SigninLogs  Sucess
#
#              Latitude           Longitude
# 0  -33.86714172363281   151.2071075439453
# 1   38.73078155517578  -78.17196655273438
# 2   38.73078155517578  -78.17196655273438
# 3   38.73078155517578  -78.17196655273438
# 4   38.73078155517578  -78.17196655273438
#
# [5 rows x 79 columns]

# %% [markdown]
# Some queries require parameters such as a account or host name to search for results in.

# %%
help(qry_prov.Office365.list_activity_for_account)
# Out:
# Help on partial in module functools:
#
# functools.partial(<bound method QueryProvider._e...fice365', query_name='list_activity_for_account')
#     Lists Office Activity for Account
#
#     Parameters
#     ----------
#     account_name: str
#         The account name to find
#     add_query_items: str (optional)
#         Additional query clauses
#     end: datetime
#         Query end time
#     start: datetime
#         Query start time
#     table: str (optional)
#         Table name
#         (default value is: OfficeActivity)

# %%
office_activity = qry_prov.Office365.list_activity_for_account(account_name="KDickens@seccxp.ninja")
office_activity.head()
# Out:
#                                TenantId Application UserDomain Activity  \
# 0  8ecf8077-cf51-4820-aadd-14040956f35d
# 1  8ecf8077-cf51-4820-aadd-14040956f35d
# 2  8ecf8077-cf51-4820-aadd-14040956f35d
# 3  8ecf8077-cf51-4820-aadd-14040956f35d
# 4  8ecf8077-cf51-4820-aadd-14040956f35d
#
#   UserAgent    RecordType             TimeGenerated          Operation  \
# 0            ExchangeItem 2023-06-25 01:12:37+00:00               Send
# 1                      50 2023-06-25 01:12:39+00:00  MailItemsAccessed
# 2            ExchangeItem 2023-06-25 01:34:04+00:00             Update
# 3            ExchangeItem 2023-06-25 01:33:33+00:00               Send
# 4                      50 2023-06-25 01:33:52+00:00  MailItemsAccessed
#
#                          OrganizationId                       OrganizationId_  \
# 0  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 1  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 2  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 3  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 4  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
#
#   UserType           UserKey OfficeWorkload ResultStatus ResultReasonType  \
# 0  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
# 1  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
# 2  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
# 3  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
# 4  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
#
#   OfficeObjectId                 UserId                UserId_       ClientIP  \
# 0                 KDickens@seccxp.ninja  KDickens@seccxp.ninja  20.190.142.40
# 1                 KDickens@seccxp.ninja  KDickens@seccxp.ninja
# 2                 KDickens@seccxp.ninja  KDickens@seccxp.ninja  52.149.166.74
# 3                 KDickens@seccxp.ninja  KDickens@seccxp.ninja  20.190.142.40
# 4                 KDickens@seccxp.ninja  KDickens@seccxp.ninja
#
#        ClientIP_ Scope Site_ ItemType EventSource Source_Name  ... TabType  \
# 0  20.190.142.40                                               ...
# 1                                                              ...
# 2  52.149.166.74                                               ...
# 3  20.190.142.40                                               ...
# 4                                                              ...
#
#   Name OldValue NewValue ItemName ChatThreadId ChatName CommunicationType  \
# 0
# 1
# 2
# 3
# 4
#
#   AADGroupId AddOnGuid AppDistributionMode TargetUserId OperationScope  \
# 0
# 1
# 2
# 3
# 4
#
#   AzureADAppId  \
# 0
# 1
# 2
# 3
# 4
#
#                                                                  OperationProperties  \
# 0                                                                               None
# 1  [{"Name":"MailAccessType","Value":"Bind"},{"Name":"IsThrottled","Value":"False"}]
# 2                                                                               None
# 3                                                                               None
# 4  [{"Name":"MailAccessType","Value":"Bind"},{"Name":"IsThrottled","Value":"False"}]
#
#                                   AppId                           ClientAppId  \
# 0  00000003-0000-0000-c000-000000000000  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 1  00000003-0000-0000-c000-000000000000  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 2
# 3  00000003-0000-0000-c000-000000000000  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 4  13937bba-652e-4c46-b222-3003f4d1ff97  13937bba-652e-4c46-b222-3003f4d1ff97
#
#   ApplicationId SRPolicyId SRPolicyName SRRuleMatchDetails IsManagedDevice  \
# 0                                                     None            None
# 1                                                     None            None
# 2                                                     None            None
# 3                                                     None            None
# 4                                                     None            None
#
#    ActorContextId_            Type _ResourceId
# 0                   OfficeActivity
# 1                   OfficeActivity
# 2                   OfficeActivity
# 3                   OfficeActivity
# 4                   OfficeActivity
#
# [5 rows x 138 columns]

# %% [markdown]
# ### Debug Tip
#
# You can get a clearer view of what a built in query actually is by adding the `"print"` keyword as the first parameter when calling it.<br>
# This will printed the parameterized query rather than run it. The printed query will include any parameter values you passed it.

# %%
from pprint import pprint
query_text = qry_prov.Office365.list_activity_for_account("print", account_name="KDickens@seccxp.ninja")
pprint(query_text)
# Out:
# (' let accountName = "KDickens@seccxp.ninja"; let account = case( accountName '
#  'has "@", tostring(split(accountName, "@")[0]), accountName has "\\\\", '
#  'tostring(split(accountName, "\\\\")[1]), accountName ); OfficeActivity | '
#  'where TimeGenerated >= datetime(2023-06-24T01:31:25.030008Z) | where '
#  'TimeGenerated <= datetime(2023-06-26T01:31:25.030008Z) | where UserId has '
#  'accountName ')

# %%
from rich import print as rprint
rprint(qry_prov.Office365.list_activity_for_account("print", account_name="KDickens@seccxp.ninja"))
# Out:
#  let accountName = "KDickens@seccxp.ninja"; let account = case( accountName has "@", tostring(split(accountName,
# "@")[0]), accountName has "\\", tostring(split(accountName, "\\")[1]), accountName ); OfficeActivity | where
# TimeGenerated >= datetime(2023-06-24T01:31:25.030008Z) | where TimeGenerated <=
# datetime(2023-06-26T01:31:25.030008Z) | where UserId has accountName

# %% [markdown]
# ## Where is it getting the start/end time parameters from?
#
# Every query provider has a `query_time` attribute that you can set
# the time boundaries of the query.
#
# Having a single query timespan is useful when you are doing lots
# of related queries.

# %%
qry_prov.query_time
# Out:
# VBox(children=(HTML(value='<h4>Set query time boundaries</h4>'), HBox(children=(DatePicker(value=datetime.date…

# %% [markdown]
# You can also supply these parameters manually
# - as datetimes
# - as a parsable datestring

# %%
office_activity = qry_prov.Office365.list_activity_for_account(
    account_name="KDickens@seccxp.ninja",
    start="2023-06-22 00:00:00",
    end="2023-06-23 00:00:00",
)
office_activity.head()
# Out:
# 2023-06-26 11:12:08,920: WARNING - Datetime with no tzinfo will be considered UTC. (_serialization#1149)
# 2023-06-26 11:12:08,921: WARNING - Datetime with no tzinfo will be considered UTC. (_serialization#1149)
#                                TenantId Application UserDomain Activity  \
# 0  8ecf8077-cf51-4820-aadd-14040956f35d
# 1  8ecf8077-cf51-4820-aadd-14040956f35d
# 2  8ecf8077-cf51-4820-aadd-14040956f35d
# 3  8ecf8077-cf51-4820-aadd-14040956f35d
# 4  8ecf8077-cf51-4820-aadd-14040956f35d
#
#   UserAgent    RecordType             TimeGenerated          Operation  \
# 0            ExchangeItem 2023-06-22 01:11:08+00:00               Send
# 1                      50 2023-06-22 01:08:34+00:00  MailItemsAccessed
# 2                      50 2023-06-22 01:08:32+00:00  MailItemsAccessed
# 3            ExchangeItem 2023-06-22 01:11:29+00:00             Update
# 4            ExchangeItem 2023-06-22 01:11:15+00:00               Send
#
#                          OrganizationId                       OrganizationId_  \
# 0  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 1  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 2  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 3  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 4  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
#
#   UserType           UserKey OfficeWorkload ResultStatus ResultReasonType  \
# 0  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
# 1  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
# 2  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
# 3  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
# 4  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
#
#   OfficeObjectId                 UserId                UserId_       ClientIP  \
# 0                 KDickens@seccxp.ninja  KDickens@seccxp.ninja  20.190.142.42
# 1                 KDickens@seccxp.ninja  KDickens@seccxp.ninja
# 2                 KDickens@seccxp.ninja  KDickens@seccxp.ninja
# 3                 KDickens@seccxp.ninja  KDickens@seccxp.ninja  52.149.166.74
# 4                 KDickens@seccxp.ninja  KDickens@seccxp.ninja  20.190.142.42
#
#        ClientIP_ Scope Site_ ItemType EventSource Source_Name  ... TabType  \
# 0  20.190.142.42                                               ...
# 1                                                              ...
# 2                                                              ...
# 3  52.149.166.74                                               ...
# 4  20.190.142.42                                               ...
#
#   Name OldValue NewValue ItemName ChatThreadId ChatName CommunicationType  \
# 0
# 1
# 2
# 3
# 4
#
#   AADGroupId AddOnGuid AppDistributionMode TargetUserId OperationScope  \
# 0
# 1
# 2
# 3
# 4
#
#   AzureADAppId  \
# 0
# 1
# 2
# 3
# 4
#
#                                                                  OperationProperties  \
# 0                                                                               None
# 1  [{"Name":"MailAccessType","Value":"Bind"},{"Name":"IsThrottled","Value":"False"}]
# 2  [{"Name":"MailAccessType","Value":"Bind"},{"Name":"IsThrottled","Value":"False"}]
# 3                                                                               None
# 4                                                                               None
#
#                                   AppId                           ClientAppId  \
# 0  00000003-0000-0000-c000-000000000000  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 1  b669c6ea-1adf-453f-b8bc-6d526592b419  b669c6ea-1adf-453f-b8bc-6d526592b419
# 2  13937bba-652e-4c46-b222-3003f4d1ff97  13937bba-652e-4c46-b222-3003f4d1ff97
# 3
# 4  00000003-0000-0000-c000-000000000000  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
#
#   ApplicationId SRPolicyId SRPolicyName SRRuleMatchDetails IsManagedDevice  \
# 0                                                     None            None
# 1                                                     None            None
# 2                                                     None            None
# 3                                                     None            None
# 4                                                     None            None
#
#    ActorContextId_            Type _ResourceId
# 0                   OfficeActivity
# 1                   OfficeActivity
# 2                   OfficeActivity
# 3                   OfficeActivity
# 4                   OfficeActivity
#
# [5 rows x 138 columns]

# %%
from msticpy.nbwidgets import QueryTime
qt = QueryTime(start="2023-06-20 00:00:00", end="2023-06-21 00:00:00")
display(qt)
qry_prov.Office365.list_activity_for_account(
    account_name="KDickens@seccxp.ninja",
    start=qt.start,
    end=qt.end,
)
# Out:
# VBox(children=(HTML(value='<h4>Set query time boundaries</h4>'), HBox(children=(DatePicker(value=datetime.date…
# 2023-06-24 19:56:54,980: WARNING - Datetime with no tzinfo will be considered UTC. (_serialization#1149)
# 2023-06-24 19:56:54,981: WARNING - Datetime with no tzinfo will be considered UTC. (_serialization#1149)
#                                  TenantId Application UserDomain Activity  \
# 0    8ecf8077-cf51-4820-aadd-14040956f35d
# 1    8ecf8077-cf51-4820-aadd-14040956f35d
# 2    8ecf8077-cf51-4820-aadd-14040956f35d
# 3    8ecf8077-cf51-4820-aadd-14040956f35d
# 4    8ecf8077-cf51-4820-aadd-14040956f35d
# ..                                    ...         ...        ...      ...
# 661  8ecf8077-cf51-4820-aadd-14040956f35d
# 662  8ecf8077-cf51-4820-aadd-14040956f35d
# 663  8ecf8077-cf51-4820-aadd-14040956f35d
# 664  8ecf8077-cf51-4820-aadd-14040956f35d
# 665  8ecf8077-cf51-4820-aadd-14040956f35d
#
#     UserAgent    RecordType             TimeGenerated          Operation  \
# 0              ExchangeItem 2023-06-20 00:15:05+00:00               Send
# 1                        50 2023-06-20 00:15:06+00:00  MailItemsAccessed
# 2              ExchangeItem 2023-06-20 00:17:51+00:00               Send
# 3              ExchangeItem 2023-06-20 00:17:56+00:00               Send
# 4                        50 2023-06-20 00:47:12+00:00  MailItemsAccessed
# ..        ...           ...                       ...                ...
# 661                      50 2023-06-20 23:55:13+00:00  MailItemsAccessed
# 662                      50 2023-06-20 23:55:13+00:00  MailItemsAccessed
# 663                      50 2023-06-20 23:55:13+00:00  MailItemsAccessed
# 664                      50 2023-06-20 23:55:13+00:00  MailItemsAccessed
# 665                      50 2023-06-20 23:55:13+00:00  MailItemsAccessed
#
#                            OrganizationId  \
# 0    4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 1    4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 2    4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 3    4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 4    4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# ..                                    ...
# 661  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 662  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 663  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 664  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 665  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
#
#                           OrganizationId_ UserType           UserKey  \
# 0    4b2462a4-bbee-495a-a0e1-f23ae524cc9c  Regular  1003200160C8B403
# 1    4b2462a4-bbee-495a-a0e1-f23ae524cc9c  Regular  1003200160C8B403
# 2    4b2462a4-bbee-495a-a0e1-f23ae524cc9c  Regular  1003200160C8B403
# 3    4b2462a4-bbee-495a-a0e1-f23ae524cc9c  Regular  1003200160C8B403
# 4    4b2462a4-bbee-495a-a0e1-f23ae524cc9c  Regular  1003200160C8B403
# ..                                    ...      ...               ...
# 661  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  Regular  1003200160C8B403
# 662  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  Regular  1003200160C8B403
# 663  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  Regular  1003200160C8B403
# 664  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  Regular  1003200160C8B403
# 665  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  Regular  1003200160C8B403
#
#     OfficeWorkload ResultStatus ResultReasonType OfficeObjectId  \
# 0         Exchange    Succeeded        Succeeded
# 1         Exchange    Succeeded        Succeeded
# 2         Exchange    Succeeded        Succeeded
# 3         Exchange    Succeeded        Succeeded
# 4         Exchange    Succeeded        Succeeded
# ..             ...          ...              ...            ...
# 661       Exchange    Succeeded        Succeeded
# 662       Exchange    Succeeded        Succeeded
# 663       Exchange    Succeeded        Succeeded
# 664       Exchange    Succeeded        Succeeded
# 665       Exchange    Succeeded        Succeeded
#
#                     UserId                UserId_       ClientIP  \
# 0    KDickens@seccxp.ninja  KDickens@seccxp.ninja  20.190.142.42
# 1    KDickens@seccxp.ninja  KDickens@seccxp.ninja
# 2    KDickens@seccxp.ninja  KDickens@seccxp.ninja  20.190.142.41
# 3    KDickens@seccxp.ninja  KDickens@seccxp.ninja  20.190.142.42
# 4    KDickens@seccxp.ninja  KDickens@seccxp.ninja
# ..                     ...                    ...            ...
# 661  KDickens@seccxp.ninja  KDickens@seccxp.ninja
# 662  KDickens@seccxp.ninja  KDickens@seccxp.ninja
# 663  KDickens@seccxp.ninja  KDickens@seccxp.ninja
# 664  KDickens@seccxp.ninja  KDickens@seccxp.ninja
# 665  KDickens@seccxp.ninja  KDickens@seccxp.ninja
#
#          ClientIP_ Scope Site_ ItemType EventSource Source_Name  ... TabType  \
# 0    20.190.142.42                                               ...
# 1                                                                ...
# 2    20.190.142.41                                               ...
# 3    20.190.142.42                                               ...
# 4                                                                ...
# ..             ...   ...   ...      ...         ...         ...  ...     ...
# 661                                                              ...
# 662                                                              ...
# 663                                                              ...
# 664                                                              ...
# 665                                                              ...
#
#     Name OldValue NewValue ItemName ChatThreadId ChatName CommunicationType  \
# 0
# 1
# 2
# 3
# 4
# ..   ...      ...      ...      ...          ...      ...               ...
# 661
# 662
# 663
# 664
# 665
#
#     AADGroupId AddOnGuid AppDistributionMode TargetUserId OperationScope  \
# 0
# 1
# 2
# 3
# 4
# ..         ...       ...                 ...          ...            ...
# 661
# 662
# 663
# 664
# 665
#
#     AzureADAppId  \
# 0
# 1
# 2
# 3
# 4
# ..           ...
# 661
# 662
# 663
# 664
# 665
#
#                                                                    OperationProperties  \
# 0                                                                                 None
# 1    [{"Name":"MailAccessType","Value":"Bind"},{"Name":"IsThrottled","Value":"False"}]
# 2                                                                                 None
# 3                                                                                 None
# 4    [{"Name":"MailAccessType","Value":"Bind"},{"Name":"IsThrottled","Value":"False"}]
# ..                                                                                 ...
# 661  [{"Name":"MailAccessType","Value":"Bind"},{"Name":"IsThrottled","Value":"False"}]
# 662  [{"Name":"MailAccessType","Value":"Bind"},{"Name":"IsThrottled","Value":"False"}]
# 663  [{"Name":"MailAccessType","Value":"Bind"},{"Name":"IsThrottled","Value":"False"}]
# 664  [{"Name":"MailAccessType","Value":"Bind"},{"Name":"IsThrottled","Value":"False"}]
# 665  [{"Name":"MailAccessType","Value":"Bind"},{"Name":"IsThrottled","Value":"False"}]
#
#                                     AppId  \
# 0    00000003-0000-0000-c000-000000000000
# 1    13937bba-652e-4c46-b222-3003f4d1ff97
# 2    00000003-0000-0000-c000-000000000000
# 3    00000003-0000-0000-c000-000000000000
# 4    b669c6ea-1adf-453f-b8bc-6d526592b419
# ..                                    ...
# 661  00000003-0000-0000-c000-000000000000
# 662  00000003-0000-0000-c000-000000000000
# 663  00000003-0000-0000-c000-000000000000
# 664  00000003-0000-0000-c000-000000000000
# 665  00000003-0000-0000-c000-000000000000
#
#                               ClientAppId ApplicationId SRPolicyId  \
# 0    d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 1    13937bba-652e-4c46-b222-3003f4d1ff97
# 2    d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 3    d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 4    b669c6ea-1adf-453f-b8bc-6d526592b419
# ..                                    ...           ...        ...
# 661  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 662  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 663  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 664  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 665  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
#
#     SRPolicyName SRRuleMatchDetails IsManagedDevice  ActorContextId_  \
# 0                              None            None
# 1                              None            None
# 2                              None            None
# 3                              None            None
# 4                              None            None
# ..           ...                ...             ...              ...
# 661                            None            None
# 662                            None            None
# 663                            None            None
# 664                            None            None
# 665                            None            None
#
#                Type _ResourceId
# 0    OfficeActivity
# 1    OfficeActivity
# 2    OfficeActivity
# 3    OfficeActivity
# 4    OfficeActivity
# ..              ...         ...
# 661  OfficeActivity
# 662  OfficeActivity
# 663  OfficeActivity
# 664  OfficeActivity
# 665  OfficeActivity
#
# [666 rows x 138 columns]

# %% [markdown]
# ## Extending queries with the `add_query_items` parameter
#
# We can also customize built in queries with by adding query items to them.

# %%
office_activity_filtered = qry_prov.Office365.list_activity_for_account(
    account_name="KDickens@seccxp.ninja",
    add_query_items="| where Operation != 'MailItemsAccessed'"
)
office_activity_filtered.head()
# Out:
#                                TenantId Application UserDomain Activity  \
# 0  8ecf8077-cf51-4820-aadd-14040956f35d
# 1  8ecf8077-cf51-4820-aadd-14040956f35d
# 2  8ecf8077-cf51-4820-aadd-14040956f35d
# 3  8ecf8077-cf51-4820-aadd-14040956f35d
# 4  8ecf8077-cf51-4820-aadd-14040956f35d
#
#   UserAgent    RecordType             TimeGenerated Operation  \
# 0            ExchangeItem 2023-06-25 01:12:37+00:00      Send
# 1            ExchangeItem 2023-06-25 01:34:04+00:00    Update
# 2            ExchangeItem 2023-06-25 01:33:33+00:00      Send
# 3            ExchangeItem 2023-06-24 01:53:12+00:00      Send
# 4            ExchangeItem 2023-06-24 01:54:38+00:00      Send
#
#                          OrganizationId                       OrganizationId_  \
# 0  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 1  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 2  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 3  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
# 4  4b2462a4-bbee-495a-a0e1-f23ae524cc9c  4b2462a4-bbee-495a-a0e1-f23ae524cc9c
#
#   UserType           UserKey OfficeWorkload ResultStatus ResultReasonType  \
# 0  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
# 1  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
# 2  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
# 3  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
# 4  Regular  1003200160C8B403       Exchange    Succeeded        Succeeded
#
#   OfficeObjectId                 UserId                UserId_       ClientIP  \
# 0                 KDickens@seccxp.ninja  KDickens@seccxp.ninja  20.190.142.40
# 1                 KDickens@seccxp.ninja  KDickens@seccxp.ninja  52.149.166.74
# 2                 KDickens@seccxp.ninja  KDickens@seccxp.ninja  20.190.142.40
# 3                 KDickens@seccxp.ninja  KDickens@seccxp.ninja  20.190.142.41
# 4                 KDickens@seccxp.ninja  KDickens@seccxp.ninja  20.190.142.41
#
#        ClientIP_ Scope Site_ ItemType EventSource Source_Name  ... TabType  \
# 0  20.190.142.40                                               ...
# 1  52.149.166.74                                               ...
# 2  20.190.142.40                                               ...
# 3  20.190.142.41                                               ...
# 4  20.190.142.41                                               ...
#
#   Name OldValue NewValue ItemName ChatThreadId ChatName CommunicationType  \
# 0
# 1
# 2
# 3
# 4
#
#   AADGroupId AddOnGuid AppDistributionMode TargetUserId OperationScope  \
# 0
# 1
# 2
# 3
# 4
#
#   AzureADAppId OperationProperties                                 AppId  \
# 0                             None  00000003-0000-0000-c000-000000000000
# 1                             None
# 2                             None  00000003-0000-0000-c000-000000000000
# 3                             None  00000003-0000-0000-c000-000000000000
# 4                             None  00000003-0000-0000-c000-000000000000
#
#                             ClientAppId ApplicationId SRPolicyId SRPolicyName  \
# 0  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 1
# 2  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 3  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
# 4  d73513d5-ad2e-46c2-a6e9-89a11b7704bb
#
#   SRRuleMatchDetails IsManagedDevice  ActorContextId_            Type  \
# 0               None            None                   OfficeActivity
# 1               None            None                   OfficeActivity
# 2               None            None                   OfficeActivity
# 3               None            None                   OfficeActivity
# 4               None            None                   OfficeActivity
#
#   _ResourceId
# 0
# 1
# 2
# 3
# 4
#
# [5 rows x 138 columns]

# %% [markdown]
# You can also add your own built in queries by specifying them in a yaml file and adding the required path to your msticpyconfig.yaml file.

# %% [markdown]
# We can also use `exec_query` to run our own queries.

# %%
query = """
OfficeActivity 
| where TimeGenerated > ago(7d) 
| where UserId =~ 'KDickens@seccxp.ninja' 
| summarize count() by Operation
"""
custom_query_df = qry_prov.exec_query(query)
custom_query_df
# Out:
#            Operation  count_
# 0               Send     730
# 1  MailItemsAccessed    3202
# 2             Update     147
# 3         SoftDelete      55
# 4             Create      18

# %% [markdown]
# When writing our own queries for a Log Analytics (or Kusto) based data source we can check the schema of any table in our connected workspace with `.schema`.<br>
# This will return a dictionary with all the tables, their column names, and the data type of each field.

# %%
qry_prov.schema['W3CIISLog']
# Out:
# {'AdditionalInformation': 'string',
#  'AzureDeploymentID': 'string',
#  'Computer': 'string',
#  'Confidence': 'string',
#  'Date': 'string',
#  'Description': 'string',
#  'FileOffset': 'int',
#  'FileUri': 'string',
#  'FirstReportedDateTime': 'string',
#  'IndicatorThreatType': 'string',
#  'IsActive': 'string',
#  'LastReportedDateTime': 'string',
#  'MG': 'guid',
#  'MaliciousIP': 'string',
#  'ManagementGroupName': 'string',
#  'RemoteIPCountry': 'string',
#  'RemoteIPLatitude': 'real',
#  'RemoteIPLongitude': 'real',
#  'ReportReferenceLink': 'string',
#  'Role': 'string',
#  'RoleInstance': 'string',
#  'Severity': 'int',
#  'SourceSystem': 'string',
#  'StorageAccount': 'string',
#  'TLPLevel': 'string',
#  'TenantId': 'guid',
#  'Time': 'string',
#  'TimeGenerated': 'datetime',
#  'TimeTaken': 'long',
#  'cIP': 'string',
#  'csBytes': 'long',
#  'csCookie': 'string',
#  'csHost': 'string',
#  'csMethod': 'string',
#  'csReferer': 'string',
#  'csUriQuery': 'string',
#  'csUriStem': 'string',
#  'csUserAgent': 'string',
#  'csUserName': 'string',
#  'csVersion': 'string',
#  'sComputerName': 'string',
#  'sIP': 'string',
#  'sPort': 'int',
#  'sSiteName': 'string',
#  'scBytes': 'long',
#  'scStatus': 'string',
#  'scSubStatus': 'string',
#  'scWin32Status': 'string'}

# %% [markdown]
# ---
# **Extra**
#
# It is also possible to add your own queries to the built in queries in MSTICPy.<br>
# See this document in our ReadTheDocs documentation
# In addition our documentation shows how to structure the required files and reference them in your configuration.<br>
# Adding queries to MSTICPy: https://msticpy.readthedocs.io/en/latest/extending/Queries.html<br>
# Also see this notebook: https://github.com/ianhelle/pycon2021/blob/main/Extending-MSTICPy.ipynb<br>

# %% [markdown]
# ## <a style="border: solid; padding:5pt; color:black; background-color:#309030">1st Exercise - Run a query</a>
#
# Execute a query against the created `qry_prov`. This can be a built in query or a custom query - its up to you.
#
# If using a built-in query, experiment with changing the `qry_prov.query_time` time range.
#
# <details>
# <summary>Hints...</summary>
# <ul>
# <li>If you add "print" as a parameter when calling a query it will print out the query rather than executing it.</li>
# <li>help(qry_prov.CAT.query_name) will show you the code and required params need to run each query in there</li>
# <li>qry_prov.SecurityAlert.list_alerts() doesn't need any extra parameters - uses the time defaults</li>
# </ul>
# </details>

# %%
qry_prov.SecurityAlert.list_alerts()
# Out:
#                                  TenantId                    TimeGenerated  \
# 0    8ecf8077-cf51-4820-aadd-14040956f35d 2023-06-24 01:34:05.824281+00:00
# 1    8ecf8077-cf51-4820-aadd-14040956f35d 2023-06-24 01:34:07.929524+00:00
# 2    8ecf8077-cf51-4820-aadd-14040956f35d 2023-06-24 01:40:57.615238+00:00
# 3    8ecf8077-cf51-4820-aadd-14040956f35d 2023-06-24 01:44:17.985954+00:00
# 4    8ecf8077-cf51-4820-aadd-14040956f35d 2023-06-24 01:46:54.557182+00:00
# ..                                    ...                              ...
# 612  8ecf8077-cf51-4820-aadd-14040956f35d 2023-06-25 00:51:08.163916+00:00
# 613  8ecf8077-cf51-4820-aadd-14040956f35d 2023-06-25 00:51:19.790412+00:00
# 614  8ecf8077-cf51-4820-aadd-14040956f35d 2023-06-25 00:51:19.821607+00:00
# 615  8ecf8077-cf51-4820-aadd-14040956f35d 2023-06-25 01:34:07.021509+00:00
# 616  8ecf8077-cf51-4820-aadd-14040956f35d 2023-06-25 02:19:15.046781+00:00
#
#                                                         AlertDisplayName  \
# 0                Palo Alto - possible internal to external port scanning
# 1                                                             WAF events
# 2                                                     InterestinIpEntity
# 3                                  TEST666-KK-series_decompose_anomalies
# 4                Palo Alto - possible internal to external port scanning
# ..                                                                   ...
# 612                             SAP - Deactivation of Security Audit Log
# 613  SAP - Anomaly Detected- Audit: Active status set to 0 in system EPT
# 614  SAP - Anomaly Detected- Audit: Active status set to 0 in system EPT
# 615              Palo Alto - possible internal to external port scanning
# 616                                Palo Alto Networks health is affected
#
#                                                                AlertName  \
# 0                Palo Alto - possible internal to external port scanning
# 1                                                             WAF events
# 2                                                     InterestinIpEntity
# 3                                  TEST666-KK-series_decompose_anomalies
# 4                Palo Alto - possible internal to external port scanning
# ..                                                                   ...
# 612                             SAP - Deactivation of Security Audit Log
# 613  SAP - Anomaly Detected- Audit: Active status set to 0 in system EPT
# 614  SAP - Anomaly Detected- Audit: Active status set to 0 in system EPT
# 615              Palo Alto - possible internal to external port scanning
# 616                                Palo Alto Networks health is affected
#
#           Severity  \
# 0              Low
# 1             High
# 2           Medium
# 3           Medium
# 4              Low
# ..             ...
# 612           High
# 613           High
# 614           High
# 615            Low
# 616  Informational
#
#                                                                                              Description  \
# 0    Identifies a list of internal Source IPs (10.x.x.x Hosts) that have triggered 10 or more non-gra...
# 1
# 2
# 3
# 4    Identifies a list of internal Source IPs (10.x.x.x Hosts) that have triggered 10 or more non-gra...
# ..                                                                                                   ...
# 612  Identifies deactivation of Security Audit Log\n\nSource Action: Disable secruity Audit Log using...
# 613  #### Detailed information\nAudit: Active status set to &1\n#### Additional information\n{"Messag...
# 614  #### Detailed information\nAudit: Active status set to &1\n#### Additional information\n{"Messag...
# 615  Identifies a list of internal Source IPs (10.x.x.x Hosts) that have triggered 10 or more non-gra...
# 616  Alert from Palo Alto Networks please look at entities section to identify the computer / devices...
#
#              ProviderName VendorName                      VendorOriginalId  \
# 0    ASI Scheduled Alerts  Microsoft  cfd3c67e-51d5-4440-a9a2-806d78251772
# 1    ASI Scheduled Alerts  Microsoft  2317adab-ef35-48f5-a2bb-110133dd5038
# 2    ASI Scheduled Alerts  Microsoft  b7d3b218-9bf6-44fb-9005-142975cbf6cb
# 3    ASI Scheduled Alerts  Microsoft  baf723c3-747d-44bd-aff2-67bb96e26c20
# 4    ASI Scheduled Alerts  Microsoft  830ef152-edfd-44c1-bf62-948018ef61aa
# ..                    ...        ...                                   ...
# 612  ASI Scheduled Alerts  Microsoft  83009103-b874-42bc-9b18-8108b7b21386
# 613  ASI Scheduled Alerts  Microsoft  4a0aed30-daa3-4d6e-a618-e2b39a447894
# 614  ASI Scheduled Alerts  Microsoft  12d06a9f-5948-4d0b-961c-ec3c7a18803f
# 615  ASI Scheduled Alerts  Microsoft  6e91ddc7-ce7b-40ee-be5a-3e5b625537a4
# 616  ASI Scheduled Alerts  Microsoft  eb60bdd2-37d7-4bef-89eb-7a9c696af63b
#
#                             SystemAlertId ResourceId SourceComputerId  \
# 0    fd927479-fe3c-8d91-d171-e72a035d7e0e
# 1    cd94fc00-5c70-0279-f03a-3acd45aa2238
# 2    0bfb1aac-bebd-0aad-f966-ded98b96032f
# 3    d6d660ec-ec21-87fb-0dd7-4680ee864a0e
# 4    7d893c13-f747-1df1-7fff-8f96055dc538
# ..                                    ...        ...              ...
# 612  7b6caef8-584e-e6d7-75ba-76ec308b2af1
# 613  a683f28f-9d5e-e20b-6761-32e3100fb606
# 614  bdd2176e-0a74-9ba6-5128-131951ce31f5
# 615  b536cd13-d234-b94f-512c-01dacdf9de3c
# 616  64870b08-b4a9-f6d9-a2a0-3f9e42c90fa4
#
#                                                                      AlertType  \
# 0    8ecf8077-cf51-4820-aadd-14040956f35d_8e21eb48-42e2-4cb6-9c31-87bdd9e13c5e
# 1    8ecf8077-cf51-4820-aadd-14040956f35d_09ae4a64-cbdb-4242-af2c-c6d02bc24510
# 2    8ecf8077-cf51-4820-aadd-14040956f35d_ec3a7b1c-5456-4819-ae0c-c454ad8598f7
# 3    8ecf8077-cf51-4820-aadd-14040956f35d_213d40a8-1f20-4978-8381-72b472737562
# 4    8ecf8077-cf51-4820-aadd-14040956f35d_d21b14e2-f357-4279-be7b-9184a47fbdba
# ..                                                                         ...
# 612  8ecf8077-cf51-4820-aadd-14040956f35d_8af1bc1d-7e7e-4aef-bdb1-285aebff0f45
# 613  8ecf8077-cf51-4820-aadd-14040956f35d_ac21f535-feff-4542-8d3d-51ab7f122bd8
# 614  8ecf8077-cf51-4820-aadd-14040956f35d_ac21f535-feff-4542-8d3d-51ab7f122bd8
# 615  8ecf8077-cf51-4820-aadd-14040956f35d_8e21eb48-42e2-4cb6-9c31-87bdd9e13c5e
# 616  8ecf8077-cf51-4820-aadd-14040956f35d_87d7f066-fcfa-4c90-ba45-f005b74ac0d7
#
#     ConfidenceLevel  ConfidenceScore  IsIncident  \
# 0                                NaN       False
# 1                                NaN       False
# 2                                NaN       False
# 3                                NaN       False
# 4                                NaN       False
# ..              ...              ...         ...
# 612                              NaN       False
# 613                              NaN       False
# 614                              NaN       False
# 615                              NaN       False
# 616                              NaN       False
#
#                         StartTimeUtc                       EndTimeUtc  \
# 0   2023-06-24 00:29:02.158000+00:00 2023-06-24 01:29:02.158000+00:00
# 1   2023-06-24 00:06:30.549687+00:00 2023-06-24 00:06:30.549687+00:00
# 2   2023-06-23 20:35:49.422000+00:00 2023-06-24 01:35:49.422000+00:00
# 3   2023-06-23 01:39:13.015000+00:00 2023-06-24 01:39:13.015000+00:00
# 4   2023-06-24 00:41:47.829000+00:00 2023-06-24 01:41:47.829000+00:00
# ..                               ...                              ...
# 612        2023-06-24 23:00:53+00:00        2023-06-24 23:57:51+00:00
# 613        2023-06-24 23:00:53+00:00        2023-06-24 23:00:53+00:00
# 614        2023-06-24 23:57:51+00:00        2023-06-24 23:57:51+00:00
# 615 2023-06-25 00:29:02.158000+00:00 2023-06-25 01:29:02.158000+00:00
# 616 2023-06-25 01:14:09.133000+00:00 2023-06-25 02:14:09.133000+00:00
#
#                    ProcessingEndTime RemediationSteps  \
# 0   2023-06-24 01:34:05.766731+00:00
# 1   2023-06-24 01:34:07.891903+00:00
# 2   2023-06-24 01:40:57.559992+00:00
# 3   2023-06-24 01:44:17.936165+00:00
# 4   2023-06-24 01:46:54.510391+00:00
# ..                               ...              ...
# 612 2023-06-25 00:51:08.078531+00:00
# 613 2023-06-25 00:51:19.702567+00:00
# 614 2023-06-25 00:51:19.733675+00:00
# 615 2023-06-25 01:34:06.968303+00:00
# 616 2023-06-25 02:19:14.994605+00:00
#
#                                                                                       ExtendedProperties  \
# 0    {"Query Period":"01:00:00","Trigger Operator":"GreaterThan","Trigger Threshold":"0","Correlation...
# 1    {"Query Period":"05:00:00","Trigger Operator":"GreaterThan","Trigger Threshold":"0","Correlation...
# 2    {"Query Period":"05:00:00","Trigger Operator":"GreaterThan","Trigger Threshold":"0","Correlation...
# 3    {"Query Period":"1.00:00:00","Trigger Operator":"GreaterThan","Trigger Threshold":"0","Correlati...
# 4    {"Query Period":"01:00:00","Trigger Operator":"GreaterThan","Trigger Threshold":"0","Correlation...
# ..                                                                                                   ...
# 612  {"Query Period":"02:00:00","Trigger Operator":"GreaterThan","Trigger Threshold":"0","Correlation...
# 613  {"Query Period":"14.00:00:00","Trigger Operator":"GreaterThan","Trigger Threshold":"0","Correlat...
# 614  {"Query Period":"14.00:00:00","Trigger Operator":"GreaterThan","Trigger Threshold":"0","Correlat...
# 615  {"Query Period":"01:00:00","Trigger Operator":"GreaterThan","Trigger Threshold":"0","Correlation...
# 616  {"Query Period":"01:00:00","Trigger Operator":"GreaterThan","Trigger Threshold":"0","Correlation...
#
#                                                                                                 Entities  \
# 0                                                  [{"$id":"2","Address":"220.245.131.215","Type":"ip"}]
# 1
# 2                                                  [{"$id":"2","Address":"128.106.117.151","Type":"ip"}]
# 3
# 4                                                  [{"$id":"2","Address":"220.245.131.215","Type":"ip"}]
# ..                                                                                                   ...
# 612  [{"$id":"2","Name":"DEVELOPER","DisplayName":"DEVELOPER","Type":"account"},{"$id":"3","Name":"pd...
# 613  [{"$id":"2","Name":"1337HX0R","DisplayName":"1337HX0R","Type":"account"},{"$id":"3","AppId":1,"N...
# 614  [{"$id":"2","Name":"DEVELOPER","DisplayName":"DEVELOPER","Type":"account"},{"$id":"3","AppId":2,...
# 615                                                [{"$id":"2","Address":"220.245.131.215","Type":"ip"}]
# 616  [{"$id":"2","DnsDomain":"124.36.22","HostName":"40","NetBiosName":"40.124.36.22","Type":"host"},...
#
#     SourceSystem               WorkspaceSubscriptionId WorkspaceResourceGroup  \
# 0      Detection  d1d8779d-38d7-4f06-91db-9cbc8de0176f                    soc
# 1      Detection  d1d8779d-38d7-4f06-91db-9cbc8de0176f                    soc
# 2      Detection  d1d8779d-38d7-4f06-91db-9cbc8de0176f                    soc
# 3      Detection  d1d8779d-38d7-4f06-91db-9cbc8de0176f                    soc
# 4      Detection  d1d8779d-38d7-4f06-91db-9cbc8de0176f                    soc
# ..           ...                                   ...                    ...
# 612    Detection  d1d8779d-38d7-4f06-91db-9cbc8de0176f                    soc
# 613    Detection  d1d8779d-38d7-4f06-91db-9cbc8de0176f                    soc
# 614    Detection  d1d8779d-38d7-4f06-91db-9cbc8de0176f                    soc
# 615    Detection  d1d8779d-38d7-4f06-91db-9cbc8de0176f                    soc
# 616    Detection  d1d8779d-38d7-4f06-91db-9cbc8de0176f                    soc
#
#     ExtendedLinks     ProductName ProductComponentName AlertLink Status  \
# 0                  Azure Sentinel     Scheduled Alerts              New
# 1                  Azure Sentinel     Scheduled Alerts              New
# 2                  Azure Sentinel     Scheduled Alerts              New
# 3                  Azure Sentinel     Scheduled Alerts              New
# 4                  Azure Sentinel     Scheduled Alerts              New
# ..            ...             ...                  ...       ...    ...
# 612                Azure Sentinel     Scheduled Alerts              New
# 613                Azure Sentinel     Scheduled Alerts              New
# 614                Azure Sentinel     Scheduled Alerts              New
# 615                Azure Sentinel     Scheduled Alerts              New
# 616                Azure Sentinel     Scheduled Alerts              New
#
#     CompromisedEntity                                    Tactics Techniques  \
# 0                                                      Discovery  ["T1046"]
# 1                                                 DefenseEvasion
# 2                                                        Unknown
# 3                                                        Unknown
# 4                                                      Discovery  ["T1046"]
# ..                ...                                        ...        ...
# 612                    Persistence, DefenseEvasion, Exfiltration
# 613                                                       Impact
# 614                                                       Impact
# 615                                                    Discovery  ["T1046"]
# 616                                                      Unknown
#
#               Type
# 0    SecurityAlert
# 1    SecurityAlert
# 2    SecurityAlert
# 3    SecurityAlert
# 4    SecurityAlert
# ..             ...
# 612  SecurityAlert
# 613  SecurityAlert
# 614  SecurityAlert
# 615  SecurityAlert
# 616  SecurityAlert
#
# [617 rows x 34 columns]

# %% [markdown]
# ---
#
# # <a style="border: solid; padding:5pt; color:black; background-color:#909090">Kusto</a>
#
# ---
#
# Sentinel isn't the only data provider available and we have plenty more that we can use to connect to.<br>
# Kusto is a popular data source for a lot of uses.
#
# We added Kusto cluster to our `msticpyconfig.yaml` file in the previous session. We will use this Kusto cluster (`https://msticpytraining.eastus.kusto.windows.net`).

# %%
from msticpy.config import  MpConfigEdit

mp.get_config("KustoClusters")
# Out:
# {'Kusto-Firecon23': {'Args': {'Cluster': 'https://msticpytraining.eastus.kusto.windows.net/',
#    'IntegratedAuth': True,
#    'TenantId': '72f988bf-86f1-41af-91ab-2d7cd011db47'}}}

# %% [markdown]
# ## <a style="border: solid; padding:5pt; color:black; background-color:#309030">2nd Exercise - Kusto</a>
#
# 1. Connect to the Kusto cluster https://msticpytraining.eastus.kusto.windows.net/ and the `msticpydata` database. <br>
# 2. Run a query to understand the schema of the Syslog table and get some data
#
#
# <details>
# <summary>Hints...</summary>
# <ul>
# <li>You need to specify a cluster to connect to - the cluster can be specified as:
#     <ul>
#     <li>A cluster friendly name - the entry name in our configuration</li>
#     <li>The full URL</li>
#     <li>Just the host part of the URL - e.g. "msticpytraining"</li>
#     </ul>
# </li>
# <li>We gave the Kusto cluster the short name "Kusto-Firecon23" in our config.</li>
# <li>https://msticpy.readthedocs.io/en/latest/data_acquisition/DataProv-Kusto-New.html has the details you need</li>
# <li>The query <pre>`Syslog | getschema`</pre> returns the schema of the Syslog table.</li>
# <li>You can specify the default database in the 'connect' call (database="msticpydata") or passing this parameter
# to 'exec_query()'
# </li>
# <li>You can also get the schema using the qry_prov.get_database_schema() function</li>
# </ul>
# </details>

# %%
kusto_prov = mp.QueryProvider("Kusto_New")
# your answer here...
kusto_prov.connect(cluster="Kusto-Firecon23", database="msticpydata")
kusto_prov.exec_query("Syslog | getschema")

# another solution
kusto_prov.connect(cluster="msticpytraining")
kusto_prov.exec_query("Syslog | getschema", database="msticpydata")
# Out:
# Warning: Custom query definitions path E:\src\msticpy-training\workshops\Jun2023\completed\data not found
#        ColumnName  ColumnOrdinal         DataType ColumnType
# 0         Column1              0     System.Int64       long
# 1        TenantId              1      System.Guid       guid
# 2    SourceSystem              2    System.String     string
# 3   TimeGenerated              3  System.DateTime   datetime
# 4        Computer              4    System.String     string
# 5       EventTime              5  System.DateTime   datetime
# 6        Facility              6    System.String     string
# 7        HostName              7    System.String     string
# 8   SeverityLevel              8    System.String     string
# 9   SyslogMessage              9    System.String     string
# 10      ProcessID             10    System.String     string
# 11         HostIP             11    System.String     string
# 12    ProcessName             12    System.String     string
# 13             MG             13      System.Guid       guid
# 14           Type             14    System.String     string
# 15    _ResourceId             15    System.String     string

# %% [markdown]
# There are also some helper functions in the Kusto query provider
# to retrieve the schema:
# - `qry_prov.get_database_schema(<database>)`
# - `qry_prov.schema[<TableName>]`

# %%
# Using the get_database_schema method
print("get_database_schema")
display(kusto_prov.get_database_schema("msticpydata")["Syslog"])

# setting a default database and using the schema property
print("schema attribute")
kusto_prov.set_database("msticpydata")
kusto_prov.schema["Syslog"]
# Out:
# get_database_schema
# {'Column1': 'Int64',
#  'TenantId': 'Guid',
#  'SourceSystem': 'String',
#  'TimeGenerated': 'DateTime',
#  'Computer': 'String',
#  'EventTime': 'DateTime',
#  'Facility': 'String',
#  'HostName': 'String',
#  'SeverityLevel': 'String',
#  'SyslogMessage': 'String',
#  'ProcessID': 'String',
#  'HostIP': 'String',
#  'ProcessName': 'String',
#  'MG': 'Guid',
#  'Type': 'String',
#  '_ResourceId': 'String'}
# schema attribute
# {'Column1': 'Int64',
#  'TenantId': 'Guid',
#  'SourceSystem': 'String',
#  'TimeGenerated': 'DateTime',
#  'Computer': 'String',
#  'EventTime': 'DateTime',
#  'Facility': 'String',
#  'HostName': 'String',
#  'SeverityLevel': 'String',
#  'SyslogMessage': 'String',
#  'ProcessID': 'String',
#  'HostIP': 'String',
#  'ProcessName': 'String',
#  'MG': 'Guid',
#  'Type': 'String',
#  '_ResourceId': 'String'}

# %% [markdown]
# ---
#
# # <a style="border: solid; padding:5pt; color:black; background-color:#909090">Microsoft Defender</a>
#
# ---
# Some data providers have different connection options, for example the Microsoft Defender for Endpoint and Microsoft 365 Defender APIs require a client application to handle authentication.<br>
# You can pass in these application details when connecting but if we are using an application secret its better to keep these in KeyVault and reference them in our config file.

# %%
# if you didn't run these earlier in the notebook
# import msticpy as mp 
# mp.init_notebook()

# %% [markdown]
# You can store multiple instances in your config file. To select what instance to connect to use the `instance` keyword.<br>
# In this example we will connect to our pre-configured Training instance.
#
# Ref: https://msticpy.readthedocs.io/en/latest/data_acquisition/DataProv-MSDefender.html#connecting-to-m365-defender

# %%
defender_prov = mp.QueryProvider("M365D")
defender_prov.connect()

# %%
defender_prov.list_queries()

# %% [markdown]
# We can also execute our own queries in the same format as with the other providers.

# %%
defender_prov.exec_query("DeviceInfo | take 10")

# %% [markdown]
# ## <a style="border: solid; padding:5pt; color:black; background-color:#309030">3rd Exercise - Defender Investigation</a>
# ### <a style="border: solid; padding:5pt; color:black; background-color:#903030">Due to setup issues this isn't working for our demo environment</a>
#
# 1. Find the remote IP address associated MDE connections to the URL 'davlenwindows.com' on 10/14/2022
# 2. Find all the hosts that have connected to that URL address since 10/01/2022
# 3. Get the file hash of the initiating process for these connections on 10/14/2022 and get all the files names associated with this hash on that day
#
#
# <details>
# <summary>Hints...</summary>
# <ul>
# <li>You can do this with built in queries or your own queries</li>
# <li>The Query Browser is your friend `qry_prov.browse()`</li>
# <li>Don't forget you can use add_query_items to add to the built in queries to customize the returned data.</li>
# </ul>
# </details>

# %%
# get url connections for to a specific url
url_connections = defender_prov.MDE.url_connections(
    start="10/14/2022", end="10/15/2022", url="davlenwindows.com"
)
url_connections['RemoteIP'].unique()

# %%
# get summarized output
defender_prov.MDE.url_connections(
    start="10/01/2022",
    end="10/15/2022",
    url="davlenwindows.com",
    add_query_items="| summarize by DeviceName"
)

# %%
# Find the SHA256 of the initiating process(es)
defender_prov.MDE.url_connections(
    start="10/14/2022",
    end="10/15/2022",
    url="davlenwindows.com",
    add_query_items="| summarize by InitiatingProcessSHA256",
)

# %%
# Find instances of the processes with this has
defender_prov.MDE.list_filehash(
    start="10/01/2022",
    end="10/15/2022",
    hash="1c84c8632c5269f24876ed9f49fa810b49f77e1e92e8918fc164c34b020f9a94",
    add_query_items="| summarize by FileName",
)

# %% [markdown]
# ---
#
# # <a style="border: solid; padding:5pt; color:black; background-color:#909090">Azure Resource Graph</a>
#
# ---
#
#
# The Azure Resource graph provides a way to get details about Azure Resources using KQL, this is something that is really useful to adding context during an investigation.<br>
# Below we are going to load our Resource Graph provider and connect using the Azure CLI tokens that we generated earlier.

# %%
res_qry_prov = mp.QueryProvider("ResourceGraph")
res_qry_prov.connect()
# Out:
# Warning: Custom query definitions path E:\src\msticpy-training\workshops\Jun2023\completed\data not found
# Connected

# %% [markdown]
# As with the other providers we can use in built queries or write our own custom queries. Hopefully by now you are familiar with this model and concept.

# %% [markdown]
# ## <a style="border: solid; padding:5pt; color:black; background-color:#309030">4th Exercise - Azure Resource Graph</a>
#
#  1 . Find out how many KeyVaults that you have access to. <br>
#  2. What resources exist in the msticpy resource group.<br>
#  3. Find the Key Vault that is detailed in your msticpyconfig.yaml file<br>
#
#
# <details>
# <summary>Hints...</summary>
# <ul>
# <li>All data in the Resource Graph is in the Resources table</li>
# <li>https://learn.microsoft.com/en-us/azure/governance/resource-graph/samples/starter?tabs=azure-cli gives you some query examples</li>
# <li>`Resources | where type =~ 'microsoft.keyvault/vaults' will show you all Keyvaults</li>
# <li>You will need to use .exec_query here</li>
# </ul>
# </details>

# %%
res_qry_prov.exec_query("Resources | where type =~ 'microsoft.keyvault/vaults'")
# or, if you can't remember the exact name (like me)
res_qry_prov.exec_query("""
Resources 
| where type contains 'key' 
| summarize count() by type, kind 
| order by count_ desc
""")
# Out:
#                               type kind  count_
# 0        microsoft.keyvault/vaults         1235
# 1  microsoft.compute/sshpublickeys          237

# %%
res_df = res_qry_prov.exec_query("Resources | where resourceGroup =~ 'msticpy'")
res_df.head()
# Out:
#                                                                                                     id  \
# 0  /subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/MSTICpy/providers/microsoft.a...
# 1  /subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/MSTICpy/providers/microsoft.a...
# 2  /subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/MSTICpy/providers/microsoft.a...
# 3  /subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/MSTICpy/providers/microsoft.a...
# 4  /subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/MSTICpy/providers/microsoft.a...
#
#                                            name  \
# 0  Failure Anomalies - ianhellepub2028186586623
# 1     Failure Anomalies - interns20213187148111
# 2  Failure Anomalies - msticamlianhel3245493529
# 3      Failure Anomalies - msticpy-link-checker
# 4     Failure Anomalies - msticpydemo8755825279
#
#                                                  type  \
# 0  microsoft.alertsmanagement/smartdetectoralertrules
# 1  microsoft.alertsmanagement/smartdetectoralertrules
# 2  microsoft.alertsmanagement/smartdetectoralertrules
# 3  microsoft.alertsmanagement/smartdetectoralertrules
# 4  microsoft.alertsmanagement/smartdetectoralertrules
#
#                                tenantId kind location resourceGroup  \
# 0  72f988bf-86f1-41af-91ab-2d7cd011db47        global       msticpy
# 1  72f988bf-86f1-41af-91ab-2d7cd011db47        global       msticpy
# 2  72f988bf-86f1-41af-91ab-2d7cd011db47        global       msticpy
# 3  72f988bf-86f1-41af-91ab-2d7cd011db47        global       msticpy
# 4  72f988bf-86f1-41af-91ab-2d7cd011db47        global       msticpy
#
#                          subscriptionId managedBy  sku  plan  identity zones  \
# 0  40dcc8bf-0478-4f3b-b275-ed0a94f2c013            NaN  None       NaN  None
# 1  40dcc8bf-0478-4f3b-b275-ed0a94f2c013            NaN  None       NaN  None
# 2  40dcc8bf-0478-4f3b-b275-ed0a94f2c013            NaN  None       NaN  None
# 3  40dcc8bf-0478-4f3b-b275-ed0a94f2c013            NaN  None       NaN  None
# 4  40dcc8bf-0478-4f3b-b275-ed0a94f2c013            NaN  None       NaN  None
#
#   extendedLocation  \
# 0             None
# 1             None
# 2             None
# 3             None
# 4             None
#
#                                                                                 properties.description  \
# 0  Failure Anomalies notifies you of an unusual rise in the rate of failed HTTP requests or depende...
# 1  Failure Anomalies notifies you of an unusual rise in the rate of failed HTTP requests or depende...
# 2  Failure Anomalies notifies you of an unusual rise in the rate of failed HTTP requests or depende...
# 3  Failure Anomalies notifies you of an unusual rise in the rate of failed HTTP requests or depende...
# 4  Failure Anomalies notifies you of an unusual rise in the rate of failed HTTP requests or depende...
#
#   properties.state properties.severity  \
# 0          Enabled                Sev3
# 1          Enabled                Sev3
# 2          Enabled                Sev3
# 3          Enabled                Sev3
# 4          Enabled                Sev3
#
#    properties.actionGroups.customWebhookPayload  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
#
#    properties.actionGroups.customEmailSubject  \
# 0                                         NaN
# 1                                         NaN
# 2                                         NaN
# 3                                         NaN
# 4                                         NaN
#
#                                                                       properties.actionGroups.groupIds  \
# 0  [/subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourcegroups/azuremlrg/providers/microsof...
# 1  [/subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourcegroups/azuremlrg/providers/microsof...
# 2  [/subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourcegroups/azuremlrg/providers/microsof...
# 3  [/subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourcegroups/azuremlrg/providers/microsof...
# 4  [/subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourcegroups/azuremlrg/providers/microsof...
#
#   properties.frequency  properties.throttling properties.detector.name  \
# 0                 PT1M                    NaN        Failure Anomalies
# 1                 PT1M                    NaN        Failure Anomalies
# 2                 PT1M                    NaN        Failure Anomalies
# 3                 PT1M                    NaN        Failure Anomalies
# 4                 PT1M                    NaN        Failure Anomalies
#
#      properties.detector.id  \
# 0  FailureAnomaliesDetector
# 1  FailureAnomaliesDetector
# 2  FailureAnomaliesDetector
# 3  FailureAnomaliesDetector
# 4  FailureAnomaliesDetector
#
#                                                                        properties.detector.description  \
# 0  Detects if your application experiences an abnormal rise in the rate of HTTP requests or depende...
# 1  Detects if your application experiences an abnormal rise in the rate of HTTP requests or depende...
# 2  Detects if your application experiences an abnormal rise in the rate of HTTP requests or depende...
# 3  Detects if your application experiences an abnormal rise in the rate of HTTP requests or depende...
# 4  Detects if your application experiences an abnormal rise in the rate of HTTP requests or depende...
#
#    ...  properties.siteConfig.routingRules properties.siteConfig.documentRoot  \
# 0  ...                                 NaN                                NaN
# 1  ...                                 NaN                                NaN
# 2  ...                                 NaN                                NaN
# 3  ...                                 NaN                                NaN
# 4  ...                                 NaN                                NaN
#
#   properties.siteConfig.storageType properties.siteConfig.experiments  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#   properties.siteConfig.nodeVersion properties.siteConfig.javaVersion  \
# 0                               NaN                               NaN
# 1                               NaN                               NaN
# 2                               NaN                               NaN
# 3                               NaN                               NaN
# 4                               NaN                               NaN
#
#   properties.siteConfig.phpVersion properties.siteConfig.machineKey  \
# 0                              NaN                              NaN
# 1                              NaN                              NaN
# 2                              NaN                              NaN
# 3                              NaN                              NaN
# 4                              NaN                              NaN
#
#   properties.siteConfig.limits properties.siteConfig.ftpsState  \
# 0                          NaN                             NaN
# 1                          NaN                             NaN
# 2                          NaN                             NaN
# 3                          NaN                             NaN
# 4                          NaN                             NaN
#
#    properties.siteConfig.alwaysOn properties.siteConfig.vnetName  \
# 0                             NaN                            NaN
# 1                             NaN                            NaN
# 2                             NaN                            NaN
# 3                             NaN                            NaN
# 4                             NaN                            NaN
#
#   properties.siteConfig.sitePort  properties.siteConfig.scmType  \
# 0                            NaN                            NaN
# 1                            NaN                            NaN
# 2                            NaN                            NaN
# 3                            NaN                            NaN
# 4                            NaN                            NaN
#
#   properties.siteConfig.cors properties.siteConfig.push properties.usageState  \
# 0                        NaN                        NaN                   NaN
# 1                        NaN                        NaN                   NaN
# 2                        NaN                        NaN                   NaN
# 3                        NaN                        NaN                   NaN
# 4                        NaN                        NaN                   NaN
#
#   properties.serverFarm properties.selfLink properties.httpsOnly  \
# 0                   NaN                 NaN                  NaN
# 1                   NaN                 NaN                  NaN
# 2                   NaN                 NaN                  NaN
# 3                   NaN                 NaN                  NaN
# 4                   NaN                 NaN                  NaN
#
#    properties.homeStamp  properties.slotName properties.owner properties.csrs  \
# 0                   NaN                  NaN              NaN             NaN
# 1                   NaN                  NaN              NaN             NaN
# 2                   NaN                  NaN              NaN             NaN
# 3                   NaN                  NaN              NaN             NaN
# 4                   NaN                  NaN              NaN             NaN
#
#   properties.cers
# 0             NaN
# 1             NaN
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 479 columns]

# %%
kv_res_df = res_qry_prov.exec_query("""
    Resources 
    | where type =~ 'microsoft.keyvault/vaults' 
    | where resourceGroup =~ 'msticpy' 
    | where name =~ 'msticpy-training'
"""
)
kv_res_df.head()
# Out:
#                                                                                                     id  \
# 0  /subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/MSTICpy/providers/Microsoft.K...
#
#                name                       type  \
# 0  msticpy-training  microsoft.keyvault/vaults
#
#                                tenantId kind location resourceGroup  \
# 0  72f988bf-86f1-41af-91ab-2d7cd011db47        eastus       msticpy
#
#                          subscriptionId managedBy   sku  plan identity zones  \
# 0  40dcc8bf-0478-4f3b-b275-ed0a94f2c013            None  None     None  None
#
#   extendedLocation properties.provisioningState  \
# 0             None                    Succeeded
#
#   properties.publicNetworkAccess                   properties.tenantId  \
# 0                        Enabled  72f988bf-86f1-41af-91ab-2d7cd011db47
#
#   properties.sku.name properties.sku.family  \
# 0            Standard                     A
#
#    properties.enabledForTemplateDeployment  \
# 0                                    False
#
#    properties.enabledForDiskEncryption  properties.enabledForDeployment  \
# 0                                False                            False
#
#    properties.softDeleteRetentionInDays  \
# 0                                    90
#
#                                                                              properties.accessPolicies  \
# 0  [{'tenantId': '72f988bf-86f1-41af-91ab-2d7cd011db47', 'permissions': {'secrets': ['Get', 'List',...
#
#    properties.enableSoftDelete  properties.enableRbacAuthorization  \
# 0                         True                               False
#
#                          properties.vaultUri
# 0  https://msticpy-training.vault.azure.net/

# %% [markdown]
# ## <a style="border: solid; padding:5pt; color:black; background-color:#309030">Bonus Exercise - Azure Resource Graph</a>
#
# CDOC received a report that the VM MSTICAlertsWin1 has been compromised.
# You need to answer the following questions:
# 1. Is this a real host?
# 2. Is it currently in use?
# 3. What IPs is it associated with?
# 4. Is it a production host?
# 5. What other resources might have been compromised?
# 6. Are there any users we can contact about this host?
#
#
# Hints:
# VMs type = "microsoft.compute/virtualmachines"
# NetInterface type = "microsoft.network/networkinterfaces"
# Interface VM = "properties.virtualMachine.id"

# %%
host_details = res_qry_prov.exec_query("Resources | where name =~ 'MSTICAlertsWin1'")
host_details.T
# Out:
#                                                                                                                                                                                                         0
# id                                                                                                    /subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/ASIHuntOMSWorkspaceRG/provide...
# name                                                                                                                                                                                      MSTICAlertsWin1
# type                                                                                                                                                                    microsoft.compute/virtualmachines
# tenantId                                                                                                                                                             72f988bf-86f1-41af-91ab-2d7cd011db47
# kind
# location                                                                                                                                                                                           eastus
# resourceGroup                                                                                                                                                                       asihuntomsworkspacerg
# subscriptionId                                                                                                                                                       40dcc8bf-0478-4f3b-b275-ed0a94f2c013
# managedBy
# sku                                                                                                                                                                                                  None
# plan                                                                                                                                                                                                 None
# zones                                                                                                                                                                                                None
# extendedLocation                                                                                                                                                                                     None
# properties.provisioningState                                                                                                                                                                    Succeeded
# properties.timeCreated                                                                                                                                                       2018-11-12T20:40:06.0459250Z
# properties.networkProfile.networkInterfaces                                                           [{'id': '/subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/ASIHuntOMSWorkspaceR...
# properties.storageProfile.imageReference.publisher                                                                                                                                 MicrosoftWindowsServer
# properties.storageProfile.imageReference.exactVersion                                                                                                                                   2016.127.20181010
# properties.storageProfile.imageReference.version                                                                                                                                                   latest
# properties.storageProfile.imageReference.sku                                                                                                                                              2016-Datacenter
# properties.storageProfile.imageReference.offer                                                                                                                                              WindowsServer
# properties.storageProfile.dataDisks                                                                                                                                                                    []
# properties.storageProfile.osDisk.name                                                                                                           MSTICAlertsWin1_OsDisk_1_52bcecd0dbd54d508de086940988ffe8
# properties.storageProfile.osDisk.createOption                                                                                                                                                   FromImage
# properties.storageProfile.osDisk.osType                                                                                                                                                           Windows
# properties.storageProfile.osDisk.managedDisk.id                                                       /subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/ASIHuntOMSWorkspaceRG/provide...
# properties.storageProfile.osDisk.caching                                                                                                                                                        ReadWrite
# properties.osProfile.computerName                                                                                                                                                         MSTICAlertsWin1
# properties.osProfile.allowExtensionOperations                                                                                                                                                        True
# properties.osProfile.windowsConfiguration.provisionVMAgent                                                                                                                                           True
# properties.osProfile.windowsConfiguration.patchSettings.assessmentMode                                                                                                                       ImageDefault
# properties.osProfile.windowsConfiguration.patchSettings.patchMode                                                                                                                           AutomaticByOS
# properties.osProfile.windowsConfiguration.enableAutomaticUpdates                                                                                                                                     True
# properties.osProfile.adminUsername                                                                                                                                                             MSTICAdmin
# properties.osProfile.secrets                                                                                                                                                                           []
# properties.hardwareProfile.vmSize                                                                                                                                                         Standard_DS2_v2
# properties.diagnosticsProfile.bootDiagnostics.enabled                                                                                                                                                True
# properties.diagnosticsProfile.bootDiagnostics.storageUri                                                                                                            https://andibl.blob.core.windows.net/
# properties.vmId                                                                                                                                                      3b8d40a2-33fa-4230-9dc1-794aabdd225c
# properties.extended.instanceView.hyperVGeneration                                                                                                                                                      V1
# properties.extended.instanceView.powerState.displayStatus                                                                                                                                  VM deallocated
# properties.extended.instanceView.powerState.level                                                                                                                                                    Info
# properties.extended.instanceView.powerState.code                                                                                                                                   PowerState/deallocated
# properties.licenseType                                                                                                                                                                     Windows_Server
# tags.platformsettings.host_environment.service.platform_optedin_for_rootcerts                                                                                                                        true
# tags.azsecpack                                                                                                                                                                                    nonprod
# identity.type                                                                                                                                                                                UserAssigned
# identity.userAssignedIdentities./subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroup...                                                                 5b17af16-a8ab-42cc-9aed-83de1b602e6f
# identity.userAssignedIdentities./subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroup...                                                                 bf011cc9-696f-4426-a6a6-28d446070d84

# %%
# extract the interface id of the VM
display(host_details.iloc[0]['properties.networkProfile.networkInterfaces'])
interface_id = host_details.iloc[0]['properties.networkProfile.networkInterfaces'][0]['id']
# Out:
# [{'id': '/subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/ASIHuntOMSWorkspaceRG/providers/Microsoft.Network/networkInterfaces/msticalertswin1822'}]

# %%
# Get the IP details for the interface.
ip_details = res_qry_prov.exec_query(
    f"Resources | where id == '{interface_id}'"
)
print("Private IP Address:",
    ip_details.iloc[0]["properties.ipConfigurations"][0]["properties"][
        "privateIPAddress"
    ]
)
pub_ip_details = res_qry_prov.exec_query(
    f"Resources | where id == '{interface_id}'"
)
display(pub_ip_details.iloc[0]["properties.ipConfigurations"])
pub_ip_id = pub_ip_details.iloc[0]["properties.ipConfigurations"][0]["properties"]["publicIPAddress"]["id"]
# Out:
# Private IP Address: 10.0.3.5
# [{'properties': {'provisioningState': 'Succeeded',
#    'privateIPAddressVersion': 'IPv4',
#    'privateIPAllocationMethod': 'Dynamic',
#    'subnet': {'id': '/subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/ASIHuntOMSWorkspaceRG/providers/Microsoft.Network/virtualNetworks/ASIHuntOMSWorkspaceRGvnet358/subnets/default'},
#    'privateIPAddress': '10.0.3.5',
#    'primary': True,
#    'publicIPAddress': {'id': '/subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/ASIHuntOMSWorkspaceRG/providers/Microsoft.Network/publicIPAddresses/MSTICAlertsWin1-ip'}},
#   'name': 'ipconfig1',
#   'type': 'Microsoft.Network/networkInterfaces/ipConfigurations',
#   'id': '/subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/ASIHuntOMSWorkspaceRG/providers/Microsoft.Network/networkInterfaces/msticalertswin1822/ipConfigurations/ipconfig1',
#   'etag': 'W/"cce8e7c8-0b8e-46d5-a9f7-16f26cf9e316"'}]

# %%
# See if we can find the public IP address
pub_ip_df = res_qry_prov.exec_query(f"""
Resources 
| where id == '{pub_ip_id}'
""").dropna(axis=1)
pub_ip_df.iloc[0]
# Out:
# id                                     /subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/ASIHuntOMSWorkspaceRG/provide...
# name                                                                                                                    MSTICAlertsWin1-ip
# type                                                                                                   microsoft.network/publicipaddresses
# tenantId                                                                                              72f988bf-86f1-41af-91ab-2d7cd011db47
# kind
# location                                                                                                                            eastus
# resourceGroup                                                                                                        asihuntomsworkspacerg
# subscriptionId                                                                                        40dcc8bf-0478-4f3b-b275-ed0a94f2c013
# managedBy
# sku.name                                                                                                                             Basic
# sku.tier                                                                                                                          Regional
# properties.provisioningState                                                                                                     Succeeded
# properties.idleTimeoutInMinutes                                                                                                          4
# properties.resourceGuid                                                                               bae6bbba-1c2d-4d54-944e-afecfab51fba
# properties.publicIPAllocationMethod                                                                                                Dynamic
# properties.publicIPAddressVersion                                                                                                     IPv4
# properties.ipConfiguration.id          /subscriptions/40dcc8bf-0478-4f3b-b275-ed0a94f2c013/resourceGroups/ASIHuntOMSWorkspaceRG/provide...
# properties.ipTags                                                                                                                       []
# Name: 0, dtype: object

# %% [markdown]
# ---
#
# # <a style="border: solid; padding:5pt; color:black; background-color:#909090">The <b>Panel</b> DataViewer</a>
#
# ---
#
#
# - Uses [Holoviz Panel](https://panel.holoviz.org/) to display interactive data widget
# - Uses the [Tabulator widget](https://panel.holoviz.org/reference/widgets/Tabulator.html)
# - Requires `panel` to be installed (you should have this installed - `pip install msticpy[all]`)
#
# Benefits
# - Allows interactive:
#   - Filtering
#   - Sorting
#   - Column selection
# - Uses paging and scrolling by default
# - Row selection can return indices or dataframe subset
# - Works in most notebook environments - does not require Jupyter or Jupyterlab extension
# - Has many built-in capabilities - parameters passed to underlying control

# %%
# Get some data to display
result_df = qry_prov.MDE.list_host_processes(host_name="workstation8.seccxp.ninja")

# %%
result_df.head()
# Out:
#                                TenantId AccountDomain AccountName  \
# 0  8ecf8077-cf51-4820-aadd-14040956f35d  nt authority      system
# 1  8ecf8077-cf51-4820-aadd-14040956f35d  nt authority      system
# 2  8ecf8077-cf51-4820-aadd-14040956f35d  nt authority      system
# 3  8ecf8077-cf51-4820-aadd-14040956f35d  nt authority      system
# 4  8ecf8077-cf51-4820-aadd-14040956f35d  nt authority      system
#
#   AccountObjectId AccountSid AccountUpn      ActionType AdditionalFields  \
# 0                   S-1-5-18             ProcessCreated             None
# 1                   S-1-5-18             ProcessCreated             None
# 2                   S-1-5-18             ProcessCreated             None
# 3                   S-1-5-18             ProcessCreated             None
# 4                   S-1-5-18             ProcessCreated             None
#
#   AppGuardContainerId                                  DeviceId  \
# 0                      d11af611b0b4bf0fb7de060bed072d537055617a
# 1                      d11af611b0b4bf0fb7de060bed072d537055617a
# 2                      d11af611b0b4bf0fb7de060bed072d537055617a
# 3                      d11af611b0b4bf0fb7de060bed072d537055617a
# 4                      d11af611b0b4bf0fb7de060bed072d537055617a
#
#                   DeviceName        FileName  \
# 0  workstation8.seccxp.ninja  powershell.exe
# 1  workstation8.seccxp.ninja  powershell.exe
# 2  workstation8.seccxp.ninja     SenseIR.exe
# 3  workstation8.seccxp.ninja      cvtres.exe
# 4  workstation8.seccxp.ninja         csc.exe
#
#                                                                  FolderPath  \
# 0                 C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe
# 1                 C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe
# 2  C:\Program Files\Windows Defender Advanced Threat Protection\SenseIR.exe
# 3                C:\Windows\Microsoft.NET\Framework64\v4.0.30319\cvtres.exe
# 4                   C:\Windows\Microsoft.NET\Framework64\v4.0.30319\csc.exe
#
#    FileSize InitiatingProcessAccountDomain InitiatingProcessAccountName  \
# 0    492032                   nt authority                       system
# 1    492032                   nt authority                       system
# 2   4145936                   nt authority                       system
# 3     52744                   nt authority                       system
# 4   2759232                   nt authority                       system
#
#   InitiatingProcessAccountObjectId InitiatingProcessAccountSid  \
# 0                                                     S-1-5-18
# 1                                                     S-1-5-18
# 2                                                     S-1-5-18
# 3                                                     S-1-5-18
# 4                                                     S-1-5-18
#
#   InitiatingProcessAccountUpn  \
# 0
# 1
# 2
# 3
# 4
#
#                                                                           InitiatingProcessCommandLine  \
# 0  "SenseIR.exe" "OfflineSenseIR" "1512" "eyJDb21tYW5kSWQiOiIiLCJEb3dubG9hZEZpbGVBY3Rpb25Db25maWciO...
# 1  "SenseIR.exe" "OfflineSenseIR" "1512" "eyJDb21tYW5kSWQiOiIiLCJEb3dubG9hZEZpbGVBY3Rpb25Db25maWciO...
# 2                                                                                        "MsSense.exe"
# 3                          "csc.exe" /noconfig /fullpaths @"C:\Windows\TEMP\vrrgc4qd\vrrgc4qd.cmdline"
# 4  powershell.exe -ExecutionPolicy AllSigned -NoProfile -NonInteractive -Command "& {$OutputEncodin...
#
#   InitiatingProcessFileName  \
# 0               SenseIR.exe
# 1               SenseIR.exe
# 2               MsSense.exe
# 3                   csc.exe
# 4            powershell.exe
#
#                                                 InitiatingProcessFolderPath  \
# 0  c:\program files\windows defender advanced threat protection\senseir.exe
# 1  c:\program files\windows defender advanced threat protection\senseir.exe
# 2  c:\program files\windows defender advanced threat protection\mssense.exe
# 3                   c:\windows\microsoft.net\framework64\v4.0.30319\csc.exe
# 4                 c:\windows\system32\windowspowershell\v1.0\powershell.exe
#
#    InitiatingProcessId InitiatingProcessIntegrityLevel  \
# 0                 3556                          System
# 1                 3556                          System
# 2                 2336                          System
# 3                 4256                          System
# 4                 3896                          System
#
#    InitiatingProcessLogonId  ... LogonId                               MD5  \
# 0                         0  ...     999  bcf01e61144d6d6325650134823198b8
# 1                         0  ...       0  bcf01e61144d6d6325650134823198b8
# 2                       999  ...       0  00b846cf83e6fbbfea7c7dca9c0a62e1
# 3                       999  ...     999  c877cbb966ea5939aa2a17b6a5160950
# 4                         0  ...     999  f65b029562077b648a6a5f6a1aa76a66
#
#             MachineGroup  \
# 0  Contoso North America
# 1  Contoso North America
# 2  Contoso North America
# 3  Contoso North America
# 4  Contoso North America
#
#                                                                                     ProcessCommandLine  \
# 0  powershell.exe -ExecutionPolicy AllSigned -NoProfile -NonInteractive -Command "& {$OutputEncodin...
# 1  powershell.exe -ExecutionPolicy AllSigned -NoProfile -NonInteractive -Command "& {$OutputEncodin...
# 2  "SenseIR.exe" "OfflineSenseIR" "1512" "eyJDb21tYW5kSWQiOiIiLCJEb3dubG9hZEZpbGVBY3Rpb25Db25maWciO...
# 3  cvtres.exe /NOLOGO /READONLY /MACHINE:IX86 "/OUT:C:\Windows\TEMP\RES41F7.tmp" "c:\Windows\Temp\v...
# 4                          "csc.exe" /noconfig /fullpaths @"C:\Windows\TEMP\vrrgc4qd\vrrgc4qd.cmdline"
#
#                ProcessCreationTime ProcessId  ProcessIntegrityLevel  \
# 0 2023-06-25 01:24:37.826532+00:00      4936                 System
# 1 2023-06-25 01:25:20.984847+00:00      3896                 System
# 2 2023-06-25 01:24:27.579657+00:00      3556                 System
# 3 2023-06-25 01:25:29.621312+00:00      2432                 System
# 4 2023-06-25 01:25:29.378560+00:00      4256                 System
#
#        ProcessTokenElevation ProcessVersionInfoCompanyName  \
# 0  TokenElevationTypeDefault         Microsoft Corporation
# 1  TokenElevationTypeDefault         Microsoft Corporation
# 2  TokenElevationTypeDefault         Microsoft Corporation
# 3  TokenElevationTypeDefault         Microsoft Corporation
# 4  TokenElevationTypeDefault         Microsoft Corporation
#
#           ProcessVersionInfoProductName ProcessVersionInfoProductVersion  \
# 0  Microsoft® Windows® Operating System                  10.0.19041.2913
# 1  Microsoft® Windows® Operating System                  10.0.19041.2913
# 2  Microsoft® Windows® Operating System               10.8471.19041.3086
# 3             Microsoft® .NET Framework                    14.10.25028.0
# 4             Microsoft® .NET Framework                       4.8.4084.0
#
#   ProcessVersionInfoInternalFileName ProcessVersionInfoOriginalFileName  \
# 0                         POWERSHELL                     PowerShell.EXE
# 1                         POWERSHELL                     PowerShell.EXE
# 2                        SenseIR.exe                        SenseIR.exe
# 3                         CVTRES.EXE                         CVTRES.EXE
# 4                            csc.exe                            csc.exe
#
#                              ProcessVersionInfoFileDescription  \
# 0                                           Windows PowerShell
# 1                                           Windows PowerShell
# 2  Windows Defender Advanced Threat Protection Sense IR module
# 3   Microsoft® Resource File To COFF Object Conversion Utility
# 4                              Visual C# Command Line Compiler
#
#   InitiatingProcessSignerType InitiatingProcessSignatureStatus ReportId  \
# 0                    OsVendor                            Valid   161864
# 1                    OsVendor                            Valid   161873
# 2                    OsVendor                            Valid   161863
# 3         OsVendorApplication                            Valid   161888
# 4                    OsVendor                            Valid   161887
#
#                                        SHA1  \
# 0  eb39e26a364ecd0691a59fcef61a90334112617e
# 1  eb39e26a364ecd0691a59fcef61a90334112617e
# 2  0394254a457fda14187eab4113d40e8be0b836ba
# 3  2a3249732f5aa4588a4a9895ffe217355041d663
# 4  528973416456c780051889ca1709510b6bf73370
#
#                                                              SHA256  \
# 0  b4e7bc24bf3f5c3da2eb6e9ec5ec10f90099defa91b820f2f3fc70dd9e4785c4
# 1  b4e7bc24bf3f5c3da2eb6e9ec5ec10f90099defa91b820f2f3fc70dd9e4785c4
# 2  40d316e489f0297657ccec4bf1c3dede39d58c3653eab8962c9608463289ff90
# 3  1fe531eac592b480aa4bd16052b909c3431434f17e7ae163d248355558ce43a6
# 4  4a6d0864e19c0368a47217c129b075dddf61a6a262388f9d21045d82f3423ed7
#
#                      TimeGenerated                        Timestamp  \
# 0 2023-06-25 01:24:37.843517+00:00 2023-06-25 01:24:37.843517+00:00
# 1 2023-06-25 01:25:20.996872+00:00 2023-06-25 01:25:20.996872+00:00
# 2 2023-06-25 01:24:27.641950+00:00 2023-06-25 01:24:27.641950+00:00
# 3 2023-06-25 01:25:29.631744+00:00 2023-06-25 01:25:29.631744+00:00
# 4 2023-06-25 01:25:29.428534+00:00 2023-06-25 01:25:29.428534+00:00
#
#   InitiatingProcessParentCreationTime    InitiatingProcessCreationTime  \
# 0    2023-06-14 03:14:32.721420+00:00 2023-06-25 01:24:27.579657+00:00
# 1    2023-06-14 03:14:32.721420+00:00 2023-06-25 01:24:27.579657+00:00
# 2    2023-06-14 03:14:22.994853+00:00 2023-06-14 03:14:32.721420+00:00
# 3    2023-06-25 01:25:20.984847+00:00 2023-06-25 01:25:29.378560+00:00
# 4    2023-06-25 01:24:27.579657+00:00 2023-06-25 01:25:20.984847+00:00
#
#   SourceSystem                 Type
# 0               DeviceProcessEvents
# 1               DeviceProcessEvents
# 2               DeviceProcessEvents
# 3               DeviceProcessEvents
# 4               DeviceProcessEvents
#
# [5 rows x 63 columns]

# %% [markdown]
# ### Panel Tabulator control

# %%
from msticpy.vis.data_viewer import DataViewer
dv = DataViewer(result_df)
dv
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'8d61b678-6605-46df-ac34-3a7ddb7a1601': {'version…

# %%
result_df.columns
# Out:
# Index(['TenantId', 'AccountDomain', 'AccountName', 'AccountObjectId',
#        'AccountSid', 'AccountUpn', 'ActionType', 'AdditionalFields',
#        'AppGuardContainerId', 'DeviceId', 'DeviceName', 'FileName',
#        'FolderPath', 'FileSize', 'InitiatingProcessAccountDomain',
#        'InitiatingProcessAccountName', 'InitiatingProcessAccountObjectId',
#        'InitiatingProcessAccountSid', 'InitiatingProcessAccountUpn',
#        'InitiatingProcessCommandLine', 'InitiatingProcessFileName',
#        'InitiatingProcessFolderPath', 'InitiatingProcessId',
#        'InitiatingProcessIntegrityLevel', 'InitiatingProcessLogonId',
#        'InitiatingProcessMD5', 'InitiatingProcessParentFileName',
#        'InitiatingProcessParentId', 'InitiatingProcessSHA1',
#        'InitiatingProcessSHA256', 'InitiatingProcessTokenElevation',
#        'InitiatingProcessFileSize', 'InitiatingProcessVersionInfoCompanyName',
#        'InitiatingProcessVersionInfoProductName',
#        'InitiatingProcessVersionInfoProductVersion',
#        'InitiatingProcessVersionInfoInternalFileName',
#        'InitiatingProcessVersionInfoOriginalFileName',
#        'InitiatingProcessVersionInfoFileDescription', 'LogonId', 'MD5',
#        'MachineGroup', 'ProcessCommandLine', 'ProcessCreationTime',
#        'ProcessId', 'ProcessIntegrityLevel', 'ProcessTokenElevation',
#        'ProcessVersionInfoCompanyName', 'ProcessVersionInfoProductName',
#        'ProcessVersionInfoProductVersion',
#        'ProcessVersionInfoInternalFileName',
#        'ProcessVersionInfoOriginalFileName',
#        'ProcessVersionInfoFileDescription', 'InitiatingProcessSignerType',
#        'InitiatingProcessSignatureStatus', 'ReportId', 'SHA1', 'SHA256',
#        'TimeGenerated', 'Timestamp', 'InitiatingProcessParentCreationTime',
#        'InitiatingProcessCreationTime', 'SourceSystem', 'Type'],
#       dtype='object')

# %% [markdown]
# ### Pre-set the columns to display

# %%
selected_columns = [
    "TimeGenerated"
    "AccountName",
    "FileName",
    "ProcessCommandLine",
    "InitiatingProcessFileName",
    "InitiatingProcessCommandLine",
]
dv = DataViewer(
    data=result_df, 
    selected_cols=selected_columns,
)
dv
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'92318d4c-040b-483e-8c3a-4cc62a960289': {'version…

# %% [markdown]
# ### Using `detail_cols` to make viewing long columns easier

# %%
dv = DataViewer(
    data=result_df, 
    selected_cols=selected_columns,
    detail_cols=["ProcessCommandLine", "InitiatingProcessCommandLine"],
)
dv
# Out:
# BokehModel(combine_events=True, render_bundle={'docs_json': {'1f87aa55-38ba-4d24-a891-1932669cb473': {'version…

# %% [markdown]
# ### Selecting rows from the data

# %%
dv.selection
# Out:
# [67, 72, 73]

# %%
dv.selected_dataframe
# Out:
#                                 TenantId AccountDomain AccountName  \
# 67  8ecf8077-cf51-4820-aadd-14040956f35d  nt authority      system
# 72  8ecf8077-cf51-4820-aadd-14040956f35d  nt authority      system
# 73  8ecf8077-cf51-4820-aadd-14040956f35d  nt authority      system
#
#    AccountObjectId AccountSid AccountUpn      ActionType AppGuardContainerId  \
# 67                   S-1-5-18             ProcessCreated
# 72                   S-1-5-18             ProcessCreated
# 73                   S-1-5-18             ProcessCreated
#
#                                     DeviceId                 DeviceName  \
# 67  d11af611b0b4bf0fb7de060bed072d537055617a  workstation8.seccxp.ninja
# 72  d11af611b0b4bf0fb7de060bed072d537055617a  workstation8.seccxp.ninja
# 73  d11af611b0b4bf0fb7de060bed072d537055617a  workstation8.seccxp.ninja
#
#              FileName  \
# 67     powershell.exe
# 72            csc.exe
# 73  PLUGScheduler.exe
#
#                                                    FolderPath  FileSize  \
# 67  C:\Windows\System32\WindowsPowerShell\v1.0\powershell.exe    492032
# 72    C:\Windows\Microsoft.NET\Framework64\v4.0.30319\csc.exe   2759232
# 73                   C:\Program Files\RUXIM\PLUGScheduler.exe    371584
#
#    InitiatingProcessAccountDomain InitiatingProcessAccountName  \
# 67                   nt authority                       system
# 72                   nt authority                       system
# 73                   nt authority                       system
#
#    InitiatingProcessAccountObjectId InitiatingProcessAccountSid  \
# 67                                                     S-1-5-18
# 72                                                     S-1-5-18
# 73                                                     S-1-5-18
#
#    InitiatingProcessAccountUpn  \
# 67
# 72
# 73
#
#                                                                            InitiatingProcessCommandLine  \
# 67  "SenseIR.exe" "OfflineSenseIR" "1428" "eyJDb21tYW5kSWQiOiIiLCJEb3dubG9hZEZpbGVBY3Rpb25Db25maWciO...
# 72  powershell.exe -ExecutionPolicy AllSigned -NoProfile -NonInteractive -Command "& {$OutputEncodin...
# 73                                                                            svchost.exe -k netsvcs -p
#
#    InitiatingProcessFileName  \
# 67               SenseIR.exe
# 72            powershell.exe
# 73               svchost.exe
#
#                                                  InitiatingProcessFolderPath  \
# 67  c:\program files\windows defender advanced threat protection\senseir.exe
# 72                 c:\windows\system32\windowspowershell\v1.0\powershell.exe
# 73                                           c:\windows\system32\svchost.exe
#
#     InitiatingProcessId InitiatingProcessIntegrityLevel  \
# 67                  468                          System
# 72                 4220                          System
# 73                 1292                          System
#
#     InitiatingProcessLogonId              InitiatingProcessMD5  ... LogonId  \
# 67                         0  00b846cf83e6fbbfea7c7dca9c0a62e1  ...       0
# 72                         0  bcf01e61144d6d6325650134823198b8  ...       0
# 73                       999  b7f884c1b74a263f746ee12a5f7c9f6a  ...     999
#
#                                  MD5           MachineGroup  \
# 67  bcf01e61144d6d6325650134823198b8  Contoso North America
# 72  f65b029562077b648a6a5f6a1aa76a66  Contoso North America
# 73  7aaaa30e9eae017d7201aea1a87ea55e  Contoso North America
#
#                                                                                      ProcessCommandLine  \
# 67  powershell.exe -ExecutionPolicy AllSigned -NoProfile -NonInteractive -Command "& {$OutputEncodin...
# 72                          "csc.exe" /noconfig /fullpaths @"C:\Windows\TEMP\4vrgsetq\4vrgsetq.cmdline"
# 73                                                                                  "PLUGscheduler.exe"
#
#                 ProcessCreationTime  ProcessId ProcessIntegrityLevel  \
# 67 2023-06-24 22:56:38.334874+00:00       4220                System
# 72 2023-06-24 22:57:25.651788+00:00       3388                System
# 73 2023-06-25 00:21:37.454172+00:00       3380                System
#
#         ProcessTokenElevation ProcessVersionInfoCompanyName  \
# 67  TokenElevationTypeDefault         Microsoft Corporation
# 72  TokenElevationTypeDefault         Microsoft Corporation
# 73  TokenElevationTypeDefault         Microsoft Corporation
#
#            ProcessVersionInfoProductName ProcessVersionInfoProductVersion  \
# 67  Microsoft® Windows® Operating System                  10.0.19041.2913
# 72             Microsoft® .NET Framework                       4.8.4084.0
# 73  Microsoft® Windows® Operating System                  10.0.19041.3028
#
#               ProcessVersionInfoInternalFileName  \
# 67                                    POWERSHELL
# 72                                       csc.exe
# 73  Windows Update LifeCycle Component Scheduler
#
#     ProcessVersionInfoOriginalFileName  \
# 67                      PowerShell.EXE
# 72                             csc.exe
# 73                   PLUGScheduler.exe
#
#                ProcessVersionInfoFileDescription InitiatingProcessSignerType  \
# 67                            Windows PowerShell                    OsVendor
# 72               Visual C# Command Line Compiler                    OsVendor
# 73  Windows Update LifeCycle Component Scheduler                    OsVendor
#
#    InitiatingProcessSignatureStatus ReportId  \
# 67                            Valid   161262
# 72                            Valid   161269
# 73                            Valid   161593
#
#                                         SHA1  \
# 67  eb39e26a364ecd0691a59fcef61a90334112617e
# 72  528973416456c780051889ca1709510b6bf73370
# 73  162c22dfd443970786a632e17b8503cab4e33d53
#
#                                                               SHA256  \
# 67  b4e7bc24bf3f5c3da2eb6e9ec5ec10f90099defa91b820f2f3fc70dd9e4785c4
# 72  4a6d0864e19c0368a47217c129b075dddf61a6a262388f9d21045d82f3423ed7
# 73  ee626a0d47eebcdbc91981f29bee79ffaa60644a34c763867dfaf9332a568b40
#
#                       TimeGenerated                        Timestamp  \
# 67 2023-06-24 22:56:38.347492+00:00 2023-06-24 22:56:38.347492+00:00
# 72 2023-06-24 22:57:25.709335+00:00 2023-06-24 22:57:25.709335+00:00
# 73 2023-06-25 00:21:37.457772+00:00 2023-06-25 00:21:37.457772+00:00
#
#    InitiatingProcessParentCreationTime    InitiatingProcessCreationTime  \
# 67    2023-06-14 03:14:32.721420+00:00 2023-06-24 22:56:28.103194+00:00
# 72    2023-06-24 22:56:28.103194+00:00 2023-06-24 22:56:38.334874+00:00
# 73    2023-06-14 03:14:22.994853+00:00 2023-06-14 03:14:26.018200+00:00
#
#    SourceSystem                 Type
# 67               DeviceProcessEvents
# 72               DeviceProcessEvents
# 73               DeviceProcessEvents
#
# [3 rows x 62 columns]
